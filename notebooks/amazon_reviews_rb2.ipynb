# %%
# !pip install datasets

# %%
import os
from dotenv import load_dotenv; load_dotenv()

from tqdm.notebook import tqdm
import pickle
import pandas as pd
import polars as pl
import numpy as np
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import json

from datasets import load_dataset

os.environ["PYTORCH_MPS_HIGH_WATERMARK_RATIO"] = "0.0"
import torch
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from sklearn.preprocessing import normalize
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity

from src.helpers import preprocessing as preproc
from src.helpers.postprocessing import get_top_k_representative_docs, from_list_to_string, safe_json_load
from src.helpers.sentiment_analysis import SentimentModel
from src.topol_modeling import TopolModeling as TOPOL
from sknetwork.clustering import Leiden
from scipy.sparse import csr_matrix
from src.openai_api import OPENAI_CLIENT, OpenAIEmbedding
from src.openai_api import chat_completion as openai_chat_completion
from src.google_ai_api import GGENAI_CLIENT, GoogleAIEmbedding, AdvancedGoogleAIEmbedding
from src.google_ai_api import chat_completion as google_chat_completion

# %%
DATA_PATH = os.getenv("DATA_PATH")
OUTPUTS_PATH = os.path.join(os.getenv("OUTPUTS_PATH"), "robustness_checks", "rb2")

DEVICE = torch.device("mps")
STOP_WORDS = list(ENGLISH_STOP_WORDS)
RANDOM_STATE = 42

# %% [markdown]
# ---
#
# # Getting data

# %%
dataset = load_dataset("amazon_polarity")
FILES_PREFIX = "amazon_reviews"

# dataset = load_dataset("yelp_review_full")
# FILES_PREFIX = "yelp_reviews"

# dataset = load_dataset("imdb")
# FILES_PREFIX = "imdb_reviews"

# dataset = load_dataset("google_play_store_reviews")
# FILES_PREFIX = "google_play_store_reviews"

# %%
X_train = [f"{title} {text}" for title, text in zip(dataset['train']['title'], dataset['train']['content'])]
X_test = [f"{title} {text}" for title, text in zip(dataset['test']['title'], dataset['test']['content'])]

y_train = dataset['train']['label']
y_test = dataset['test']['label']

# X = X_train + X_test
# y = y_train + y_test

data = pd.DataFrame({ 'text': X_train, 'label': y_train })

# %%
N_SAMPLE = 5000

df_A = data[data['label'] == 1].sample(N_SAMPLE, random_state=RANDOM_STATE)
df_B = data[data['label'] == 0].sample(N_SAMPLE, random_state=RANDOM_STATE)
df = pd.concat([df_A, df_B], axis=0).reset_index(drop=True)

# %%
print(len(df[df["label"] == 0]), len(df[df["label"] == 1]))
df
# Out:
# 5000 5000
#                                                    text  label
# 0     Perfect Mantra I've been looking for this mant...      1
# 1     Quality I'm just a little disapointed with the...      1
# 2     Exceptional murder-mystery writer scores big. ...      1
# 3     all the prodding questions you never wanted to...      1
# 4     Best Wok ever I am so glad I bought this wok. ...      1
# ...                                                 ...    ...
# 9995  Doesn't work for me While I applaud the focus ...      0
# 9996  Beyond Stupid One wonders about all the people...      0
# 9997  Buyer Be Very Wary The trusted leader in child...      0
# 9998  I'll bring earplugs to the state fair next yea...      0
# 9999  Melody The reason why I didn't like this produ...      0
#
# [10000 rows x 2 columns]

# %%
word_counts = df["text"].apply(lambda x: len(x.split()))
q1_word_counts = word_counts.quantile(0.25)
q2_word_counts = word_counts.quantile(0.50)
avg_word_counts = word_counts.mean()
q3_word_counts = word_counts.quantile(0.75)
q4_word_counts = word_counts.quantile(0.95)
plt.figure(figsize=(10, 5))
plt.hist(word_counts, bins=50, color='blue', alpha=0.7)
plt.axvline(q1_word_counts, color='red', linestyle='dashed', linewidth=1, label=f'Q1: {q1_word_counts:.2f}')
plt.axvline(q2_word_counts, color='green', linestyle='dashed', linewidth=1, label=f'Q2: {q2_word_counts:.2f}')
plt.axvline(avg_word_counts, color='orange', linestyle='dashed', linewidth=1, label=f'Avg: {avg_word_counts:.2f}')
plt.axvline(q3_word_counts, color='purple', linestyle='dashed', linewidth=1, label=f'Q3: {q3_word_counts:.2f}')
plt.axvline(q4_word_counts, color='brown', linestyle='dashed', linewidth=1, label=f'Q4: {q4_word_counts:.2f}')
plt.legend()
plt.xlabel("Word Count")
plt.ylabel("Frequency")
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# ---
#
# # Pre-processing data

# %% [markdown]
# ##### 1. Data cleaning

# %%
entities_to_mask = ["DATE", "TIME", "ORGANIZATION", "NUM", "LOCATION"]
STOP_WORDS += entities_to_mask

fpath = os.path.join(DATA_PATH, f"{FILES_PREFIX}_texts.pickle")
if os.path.exists(fpath):
    print(f"Loading cleaned texts from {fpath}")
    with open(fpath, "rb") as f:
        texts = pickle.load(f)
    print(f"Loaded {len(texts)} texts")
else:
    print(f"Generating cleaned texts for {len(df)} raw texts...")
    texts = []
    for i, row in tqdm(df.iterrows(), total=len(df)):
        cleaned_text = preproc.get_clean_text(row, entities_to_mask=entities_to_mask, max_lenght=5000)
        texts.append(cleaned_text)
    with open(fpath, "wb") as f:
        pickle.dump(texts, f)
    print(f"Saved {len(texts)} cleaned texts to {fpath}.")

df["text"] = texts
del fpath
# Out:
# Loading cleaned texts from /Users/tig1/Programming/TOPOL/data/amazon_reviews_texts.pickle
# Loaded 10000 texts

# %% [markdown]
# ##### 2. Embedding texts

# %%
EMBEDDING_MODEL = OpenAIEmbedding(model="text-embedding-3-small")
# EMBEDDING_MODEL = GoogleAIEmbedding(model="text-embedding-004")
# EMBEDDING_MODEL = AdvancedGoogleAIEmbedding(model='text-embedding-004', task='clustering')
# EMBEDDING_MODEL = SentenceTransformer('intfloat/multilingual-e5-large-instruct', device=DEVICE)

fpath = os.path.join(DATA_PATH, f"{FILES_PREFIX}_embeddings.pickle")
if os.path.exists(fpath):
    print(f"Loading embeddings from {fpath}")
    with open(fpath, "rb") as f:
        embeddings = pickle.load(f)
    print(f"Loaded {len(embeddings)} embeddings")
else:
    print(f"Generating embeddings for {len(df)} text...")
    embeddings = EMBEDDING_MODEL.encode(df["text"].tolist(), fast=False)
    with open(fpath, "wb") as f:
        pickle.dump(embeddings, f)
    print(f"Saved {len(embeddings)} embeddings to {fpath}.")

df["embedding"] = embeddings.tolist()
del fpath
# Out:
# Loading embeddings from /Users/tig1/Programming/TOPOL/data/amazon_reviews_embeddings.pickle
# Loaded 10000 embeddings

# %% [markdown]
# ##### 3.a. Sentiment Analysis: FinBERT

# %%
sentiment_model = SentimentModel(model_name="ProsusAI/finbert", device=DEVICE, n_special_tokens=5)

fpath = os.path.join(DATA_PATH, f"{FILES_PREFIX}_sentiments_finbert.pickle")
if os.path.exists(fpath):
    print(f"Loading sentiments from {fpath}")
    with open(fpath, "rb") as f:
        sentiments = pickle.load(f)
    print(f"Loaded {len(sentiments)} sentiments")
else:
    print(f"Generating sentiments for {len(df)} texts...")
    sentiments = []
    for idx, row in tqdm(df.iterrows(), total=len(df)):
        doc = row['text']
        temp_sentiment = sentiment_model(doc, truncation=False)
        sentiments.append(temp_sentiment)
    with open(fpath, "wb") as f:
        pickle.dump(sentiments, f)
    print(f"Saved {len(sentiments)} sentiments to {fpath}.")

df["sentiment_finbert"] = sentiments
df["sentiment_score_finbert"] = df["sentiment_finbert"].apply(sentiment_model.get_sentiment_score)
del fpath, sentiment_model
# Out:
# Device set to use mps
# Loading sentiments from /Users/tig1/Programming/TOPOL/data/amazon_reviews_sentiments_finbert.pickle
# Loaded 10000 sentiments

# %% [markdown]
# ##### 3.b. Sentiment Analysis: Multilingual DistilBERT

# %%
sentiment_model = SentimentModel(model_name="tabularisai/multilingual-sentiment-analysis", device=DEVICE, n_special_tokens=5)

fpath = os.path.join(DATA_PATH, f"{FILES_PREFIX}_sentiments_distilbert.pickle")
if os.path.exists(fpath):
    print(f"Loading sentiments from {fpath}")
    with open(fpath, "rb") as f:
        sentiments = pickle.load(f)
    print(f"Loaded {len(sentiments)} sentiments")
else:
    print(f"Generating sentiments for {len(df)} texts...")
    sentiments = []
    for idx, row in tqdm(df.iterrows(), total=len(df)):
        doc = row['text']
        temp_sentiment = sentiment_model(doc, truncation=False)
        sentiments.append(temp_sentiment)
    with open(fpath, "wb") as f:
        pickle.dump(sentiments, f)
    print(f"Saved {len(sentiments)} sentiments to {fpath}.")

df["sentiment_distilbert"] = sentiments
df["sentiment_score_distilbert"] = df["sentiment_distilbert"].apply(sentiment_model.get_sentiment_score)
del fpath, sentiment_model
# Out:
# Device set to use mps
# Loading sentiments from /Users/tig1/Programming/TOPOL/data/amazon_reviews_sentiments_distilbert.pickle
# Loaded 10000 sentiments

# %% [markdown]
# # TOPol Modeling

# %% [markdown]
# ### Create TOPol model object

# %%
umap_params = {
    # 'n_neighbors': 100, --- IGNORE ---
    'n_neighbors': 150, # Robustness check 2: Increase n_neighbors
    'min_dist': 0.0,
    'metric': 'cosine', # do not change this
}

leiden_params = {
    'resolution': 1.5,
    'modularity': 'dugue', # do not change this
}

topol_model = TOPOL(
    n_components=50,
    umap_model_params=umap_params,
    leiden_model_params=leiden_params,
    random_state=RANDOM_STATE,
)

# %% [markdown]
# ### Fit TOPol model

# %%
df = pl.from_pandas(df)
topol_model.fit(df)
# Out:
# UMAP applied successfully.
# Leiden clustering applied successfully.

# %% [markdown]
# ### Default setup analysis

# %%
cb0_cluster_info, cb1_cluster_info = topol_model.get_cluster_info(label_col="label")

# %%
cb0_cluster_info
# Out:
# shape: (15, 9)
# ┌─────────┬──────┬──────────┬─────────────┬───┬─────────────┬────────────┬────────────┬────────────┐
# │ cluster ┆ size ┆ avg_prob ┆ centroid    ┆ … ┆ 2D_centroid ┆ cosine_dis ┆ l2_dispers ┆ dot_produc │
# │ ---     ┆ ---  ┆ ---      ┆ ---         ┆   ┆ ---         ┆ persion    ┆ ion        ┆ t_dispersi │
# │ i32     ┆ i32  ┆ f64      ┆ array[f64,  ┆   ┆ array[f64,  ┆ ---        ┆ ---        ┆ on         │
# │         ┆      ┆          ┆ 1536]       ┆   ┆ 2]          ┆ f64        ┆ f64        ┆ ---        │
# │         ┆      ┆          ┆             ┆   ┆             ┆            ┆            ┆ f64        │
# ╞═════════╪══════╪══════════╪═════════════╪═══╪═════════════╪════════════╪════════════╪════════════╡
# │ 0       ┆ 505  ┆ 0.90623  ┆ [0.004234,  ┆ … ┆ [-3.118112, ┆ 0.406806   ┆ 0.803007   ┆ 0.648121   │
# │         ┆      ┆          ┆ 0.00668, …  ┆   ┆ 10.776562]  ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.01160…   ┆   ┆             ┆            ┆            ┆            │
# │ 1       ┆ 626  ┆ 0.843841 ┆ [-0.011195, ┆ … ┆ [-2.651405, ┆ 0.410523   ┆ 0.80525    ┆ 0.652517   │
# │         ┆      ┆          ┆ 0.043219, … ┆   ┆ 8.027004]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.000…     ┆   ┆             ┆            ┆            ┆            │
# │ 2       ┆ 793  ┆ 0.754748 ┆ [-0.016654, ┆ … ┆ [4.008823,  ┆ 0.46092    ┆ 0.840711   ┆ 0.709393   │
# │         ┆      ┆          ┆ 0.009968, … ┆   ┆ 8.389675]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.0047…     ┆   ┆             ┆            ┆            ┆            │
# │ 3       ┆ 510  ┆ 0.654765 ┆ [0.001033,  ┆ … ┆ [3.119137,  ┆ 0.484523   ┆ 0.855552   ┆ 0.734283   │
# │         ┆      ┆          ┆ 0.018552, … ┆   ┆ 6.91339]    ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0017…    ┆   ┆             ┆            ┆            ┆            │
# │ 4       ┆ 411  ┆ 0.665202 ┆ [-0.015526, ┆ … ┆ [4.305957,  ┆ 0.467814   ┆ 0.845192   ┆ 0.716778   │
# │         ┆      ┆          ┆ 0.021919, … ┆   ┆ 7.101313]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.001…     ┆   ┆             ┆            ┆            ┆            │
# │ …       ┆ …    ┆ …        ┆ …           ┆ … ┆ …           ┆ …          ┆ …          ┆ …          │
# │ 10      ┆ 112  ┆ 0.577768 ┆ [-0.011579, ┆ … ┆ [4.025653,  ┆ 0.453566   ┆ 0.836635   ┆ 0.70141    │
# │         ┆      ┆          ┆ 0.004577, … ┆   ┆ 6.169998]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.0069…     ┆   ┆             ┆            ┆            ┆            │
# │ 11      ┆ 126  ┆ 0.755412 ┆ [-0.009188, ┆ … ┆ [1.034217,  ┆ 0.395574   ┆ 0.794482   ┆ 0.63467    │
# │         ┆      ┆          ┆ 0.029346, … ┆   ┆ 7.055465]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.0154…     ┆   ┆             ┆            ┆            ┆            │
# │ 12      ┆ 87   ┆ 0.635696 ┆ [-0.012357, ┆ … ┆ [3.233072,  ┆ 0.393766   ┆ 0.792494   ┆ 0.63248    │
# │         ┆      ┆          ┆ 0.010862, … ┆   ┆ 8.68218]    ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.0085…     ┆   ┆             ┆            ┆            ┆            │
# │ 13      ┆ 8    ┆ 0.280685 ┆ [0.000095,  ┆ … ┆ [3.069543,  ┆ 0.390946   ┆ 0.790868   ┆ 0.629053   │
# │         ┆      ┆          ┆ 0.033877, … ┆   ┆ 7.583538]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0047…    ┆   ┆             ┆            ┆            ┆            │
# │ 14      ┆ 47   ┆ 0.642029 ┆ [-0.013735, ┆ … ┆ [-0.423775, ┆ 0.35472    ┆ 0.759231   ┆ 0.583614   │
# │         ┆      ┆          ┆ 0.029249, … ┆   ┆ 5.762559]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.007…     ┆   ┆             ┆            ┆            ┆            │
# └─────────┴──────┴──────────┴─────────────┴───┴─────────────┴────────────┴────────────┴────────────┘

# %%
cb0_cluster_info
# Out:
# shape: (15, 9)
# ┌─────────┬──────┬──────────┬─────────────┬───┬─────────────┬────────────┬────────────┬────────────┐
# │ cluster ┆ size ┆ avg_prob ┆ centroid    ┆ … ┆ 2D_centroid ┆ cosine_dis ┆ l2_dispers ┆ dot_produc │
# │ ---     ┆ ---  ┆ ---      ┆ ---         ┆   ┆ ---         ┆ persion    ┆ ion        ┆ t_dispersi │
# │ i32     ┆ i32  ┆ f64      ┆ array[f64,  ┆   ┆ array[f64,  ┆ ---        ┆ ---        ┆ on         │
# │         ┆      ┆          ┆ 1536]       ┆   ┆ 2]          ┆ f64        ┆ f64        ┆ ---        │
# │         ┆      ┆          ┆             ┆   ┆             ┆            ┆            ┆ f64        │
# ╞═════════╪══════╪══════════╪═════════════╪═══╪═════════════╪════════════╪════════════╪════════════╡
# │ 0       ┆ 505  ┆ 0.90623  ┆ [0.004234,  ┆ … ┆ [-3.118112, ┆ 0.406806   ┆ 0.803007   ┆ 0.648121   │
# │         ┆      ┆          ┆ 0.00668, …  ┆   ┆ 10.776562]  ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.01160…   ┆   ┆             ┆            ┆            ┆            │
# │ 1       ┆ 626  ┆ 0.843841 ┆ [-0.011195, ┆ … ┆ [-2.651405, ┆ 0.410523   ┆ 0.80525    ┆ 0.652517   │
# │         ┆      ┆          ┆ 0.043219, … ┆   ┆ 8.027004]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.000…     ┆   ┆             ┆            ┆            ┆            │
# │ 2       ┆ 793  ┆ 0.754748 ┆ [-0.016654, ┆ … ┆ [4.008823,  ┆ 0.46092    ┆ 0.840711   ┆ 0.709393   │
# │         ┆      ┆          ┆ 0.009968, … ┆   ┆ 8.389675]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.0047…     ┆   ┆             ┆            ┆            ┆            │
# │ 3       ┆ 510  ┆ 0.654765 ┆ [0.001033,  ┆ … ┆ [3.119137,  ┆ 0.484523   ┆ 0.855552   ┆ 0.734283   │
# │         ┆      ┆          ┆ 0.018552, … ┆   ┆ 6.91339]    ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0017…    ┆   ┆             ┆            ┆            ┆            │
# │ 4       ┆ 411  ┆ 0.665202 ┆ [-0.015526, ┆ … ┆ [4.305957,  ┆ 0.467814   ┆ 0.845192   ┆ 0.716778   │
# │         ┆      ┆          ┆ 0.021919, … ┆   ┆ 7.101313]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.001…     ┆   ┆             ┆            ┆            ┆            │
# │ …       ┆ …    ┆ …        ┆ …           ┆ … ┆ …           ┆ …          ┆ …          ┆ …          │
# │ 10      ┆ 112  ┆ 0.577768 ┆ [-0.011579, ┆ … ┆ [4.025653,  ┆ 0.453566   ┆ 0.836635   ┆ 0.70141    │
# │         ┆      ┆          ┆ 0.004577, … ┆   ┆ 6.169998]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.0069…     ┆   ┆             ┆            ┆            ┆            │
# │ 11      ┆ 126  ┆ 0.755412 ┆ [-0.009188, ┆ … ┆ [1.034217,  ┆ 0.395574   ┆ 0.794482   ┆ 0.63467    │
# │         ┆      ┆          ┆ 0.029346, … ┆   ┆ 7.055465]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.0154…     ┆   ┆             ┆            ┆            ┆            │
# │ 12      ┆ 87   ┆ 0.635696 ┆ [-0.012357, ┆ … ┆ [3.233072,  ┆ 0.393766   ┆ 0.792494   ┆ 0.63248    │
# │         ┆      ┆          ┆ 0.010862, … ┆   ┆ 8.68218]    ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.0085…     ┆   ┆             ┆            ┆            ┆            │
# │ 13      ┆ 8    ┆ 0.280685 ┆ [0.000095,  ┆ … ┆ [3.069543,  ┆ 0.390946   ┆ 0.790868   ┆ 0.629053   │
# │         ┆      ┆          ┆ 0.033877, … ┆   ┆ 7.583538]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0047…    ┆   ┆             ┆            ┆            ┆            │
# │ 14      ┆ 47   ┆ 0.642029 ┆ [-0.013735, ┆ … ┆ [-0.423775, ┆ 0.35472    ┆ 0.759231   ┆ 0.583614   │
# │         ┆      ┆          ┆ 0.029249, … ┆   ┆ 5.762559]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.007…     ┆   ┆             ┆            ┆            ┆            │
# └─────────┴──────┴──────────┴─────────────┴───┴─────────────┴────────────┴────────────┴────────────┘

# %%
fig, ax = topol_model.visualize(label_col="label")
fig.savefig(os.path.join(OUTPUTS_PATH, f"{FILES_PREFIX}_default_topol_clusters.pdf"), format="pdf", bbox_inches='tight')
plt.show(fig, ax)
# Out:
# Drift computed successfully, ready to visualize.

# %% [markdown]
# ### Randomized contextual boundary analysis

# %%
random_cb0_cluster_info, random_cb1_cluster_info = topol_model.get_cluster_info(label_col="random_label")

# %%
random_cb0_cluster_info
# Out:
# shape: (15, 9)
# ┌─────────┬──────┬──────────┬─────────────┬───┬─────────────┬────────────┬────────────┬────────────┐
# │ cluster ┆ size ┆ avg_prob ┆ centroid    ┆ … ┆ 2D_centroid ┆ cosine_dis ┆ l2_dispers ┆ dot_produc │
# │ ---     ┆ ---  ┆ ---      ┆ ---         ┆   ┆ ---         ┆ persion    ┆ ion        ┆ t_dispersi │
# │ i32     ┆ i32  ┆ f64      ┆ array[f64,  ┆   ┆ array[f64,  ┆ ---        ┆ ---        ┆ on         │
# │         ┆      ┆          ┆ 1536]       ┆   ┆ 2]          ┆ f64        ┆ f64        ┆ ---        │
# │         ┆      ┆          ┆             ┆   ┆             ┆            ┆            ┆ f64        │
# ╞═════════╪══════╪══════════╪═════════════╪═══╪═════════════╪════════════╪════════════╪════════════╡
# │ 0       ┆ 679  ┆ 0.92692  ┆ [0.007493,  ┆ … ┆ [-3.608353, ┆ 0.444257   ┆ 0.830182   ┆ 0.69115    │
# │         ┆      ┆          ┆ -0.00434, … ┆   ┆ 10.761001]  ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0158…    ┆   ┆             ┆            ┆            ┆            │
# │ 1       ┆ 705  ┆ 0.833591 ┆ [-0.003711, ┆ … ┆ [-2.402806, ┆ 0.47358    ┆ 0.848843   ┆ 0.722882   │
# │         ┆      ┆          ┆ 0.034084, … ┆   ┆ 7.742331]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.004…     ┆   ┆             ┆            ┆            ┆            │
# │ 2       ┆ 541  ┆ 0.746139 ┆ [-0.013532, ┆ … ┆ [4.001907,  ┆ 0.491914   ┆ 0.859963   ┆ 0.741848   │
# │         ┆      ┆          ┆ 0.004017, … ┆   ┆ 8.40719]    ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.0044…     ┆   ┆             ┆            ┆            ┆            │
# │ 3       ┆ 438  ┆ 0.660621 ┆ [0.006746,  ┆ … ┆ [2.971977,  ┆ 0.522632   ┆ 0.877714   ┆ 0.77212    │
# │         ┆      ┆          ┆ 0.01134, …  ┆   ┆ 6.787163]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.00116…   ┆   ┆             ┆            ┆            ┆            │
# │ 4       ┆ 426  ┆ 0.673768 ┆ [-0.005458, ┆ … ┆ [4.20687,   ┆ 0.513166   ┆ 0.872668   ┆ 0.762993   │
# │         ┆      ┆          ┆ 0.006803, … ┆   ┆ 7.073717]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.000…     ┆   ┆             ┆            ┆            ┆            │
# │ …       ┆ …    ┆ …        ┆ …           ┆ … ┆ …           ┆ …          ┆ …          ┆ …          │
# │ 10      ┆ 116  ┆ 0.605867 ┆ [-0.002977, ┆ … ┆ [3.878006,  ┆ 0.500894   ┆ 0.865865   ┆ 0.750893   │
# │         ┆      ┆          ┆ 0.001171, … ┆   ┆ 6.055939]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.0049…     ┆   ┆             ┆            ┆            ┆            │
# │ 11      ┆ 124  ┆ 0.763375 ┆ [-0.002891, ┆ … ┆ [0.784145,  ┆ 0.429215   ┆ 0.818828   ┆ 0.674205   │
# │         ┆      ┆          ┆ 0.025344, … ┆   ┆ 7.043749]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.0103…     ┆   ┆             ┆            ┆            ┆            │
# │ 12      ┆ 87   ┆ 0.632718 ┆ [-0.001983, ┆ … ┆ [3.260012,  ┆ 0.436697   ┆ 0.823845   ┆ 0.68269    │
# │         ┆      ┆          ┆ 0.006561, … ┆   ┆ 8.532483]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.0056…     ┆   ┆             ┆            ┆            ┆            │
# │ 13      ┆ 81   ┆ 0.512184 ┆ [0.005416,  ┆ … ┆ [2.104519,  ┆ 0.445207   ┆ 0.830739   ┆ 0.692204   │
# │         ┆      ┆          ┆ 0.003024, … ┆   ┆ 7.380174]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.00080…    ┆   ┆             ┆            ┆            ┆            │
# │ 14      ┆ 58   ┆ 0.64283  ┆ [-0.005138, ┆ … ┆ [0.019851,  ┆ 0.421692   ┆ 0.812909   ┆ 0.66556    │
# │         ┆      ┆          ┆ 0.01865, …  ┆   ┆ 5.720818]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0084…    ┆   ┆             ┆            ┆            ┆            │
# └─────────┴──────┴──────────┴─────────────┴───┴─────────────┴────────────┴────────────┴────────────┘

# %%
random_cb1_cluster_info
# Out:
# shape: (15, 9)
# ┌─────────┬──────┬──────────┬─────────────┬───┬─────────────┬────────────┬────────────┬────────────┐
# │ cluster ┆ size ┆ avg_prob ┆ centroid    ┆ … ┆ 2D_centroid ┆ cosine_dis ┆ l2_dispers ┆ dot_produc │
# │ ---     ┆ ---  ┆ ---      ┆ ---         ┆   ┆ ---         ┆ persion    ┆ ion        ┆ t_dispersi │
# │ i32     ┆ i32  ┆ f64      ┆ array[f64,  ┆   ┆ array[f64,  ┆ ---        ┆ ---        ┆ on         │
# │         ┆      ┆          ┆ 1536]       ┆   ┆ 2]          ┆ f64        ┆ f64        ┆ ---        │
# │         ┆      ┆          ┆             ┆   ┆             ┆            ┆            ┆ f64        │
# ╞═════════╪══════╪══════════╪═════════════╪═══╪═════════════╪════════════╪════════════╪════════════╡
# │ 0       ┆ 721  ┆ 0.915766 ┆ [0.00959,   ┆ … ┆ [-3.568986, ┆ 0.447955   ┆ 0.83243    ┆ 0.695246   │
# │         ┆      ┆          ┆ -0.00297, … ┆   ┆ 10.721733]  ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.01615…   ┆   ┆             ┆            ┆            ┆            │
# │ 1       ┆ 630  ┆ 0.842227 ┆ [-0.004501, ┆ … ┆ [-2.392777, ┆ 0.465452   ┆ 0.843477   ┆ 0.714259   │
# │         ┆      ┆          ┆ 0.034966, … ┆   ┆ 7.733685]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.004…     ┆   ┆             ┆            ┆            ┆            │
# │ 2       ┆ 597  ┆ 0.757637 ┆ [-0.013303, ┆ … ┆ [4.018707,  ┆ 0.487667   ┆ 0.857501   ┆ 0.737515   │
# │         ┆      ┆          ┆ 0.004213, … ┆   ┆ 8.430026]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.0027…     ┆   ┆             ┆            ┆            ┆            │
# │ 3       ┆ 464  ┆ 0.661269 ┆ [0.008475,  ┆ … ┆ [2.913031,  ┆ 0.524696   ┆ 0.87898    ┆ 0.774086   │
# │         ┆      ┆          ┆ 0.012496, … ┆   ┆ 6.795357]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0013…    ┆   ┆             ┆            ┆            ┆            │
# │ 4       ┆ 473  ┆ 0.69163  ┆ [-0.008286, ┆ … ┆ [4.239334,  ┆ 0.508788   ┆ 0.870187   ┆ 0.758711   │
# │         ┆      ┆          ┆ 0.010095, … ┆   ┆ 7.048474]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.002…     ┆   ┆             ┆            ┆            ┆            │
# │ …       ┆ …    ┆ …        ┆ …           ┆ … ┆ …           ┆ …          ┆ …          ┆ …          │
# │ 10      ┆ 121  ┆ 0.603248 ┆ [-0.00432,  ┆ … ┆ [3.925748,  ┆ 0.490352   ┆ 0.859477   ┆ 0.740259   │
# │         ┆      ┆          ┆ -0.003982,  ┆   ┆ 6.108393]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ … 0.0040…   ┆   ┆             ┆            ┆            ┆            │
# │ 11      ┆ 110  ┆ 0.758632 ┆ [0.000439,  ┆ … ┆ [0.948356,  ┆ 0.43208    ┆ 0.820927   ┆ 0.677467   │
# │         ┆      ┆          ┆ 0.019962, … ┆   ┆ 7.019727]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.01240…    ┆   ┆             ┆            ┆            ┆            │
# │ 12      ┆ 69   ┆ 0.645772 ┆ [-0.003843, ┆ … ┆ [3.228531,  ┆ 0.409838   ┆ 0.805891   ┆ 0.651709   │
# │         ┆      ┆          ┆ -0.001591,  ┆   ┆ 8.677153]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ … 0.006…    ┆   ┆             ┆            ┆            ┆            │
# │ 13      ┆ 61   ┆ 0.487305 ┆ [0.009418,  ┆ … ┆ [2.254859,  ┆ 0.461495   ┆ 0.840875   ┆ 0.710012   │
# │         ┆      ┆          ┆ 0.003774, … ┆   ┆ 7.3805]     ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.00694…    ┆   ┆             ┆            ┆            ┆            │
# │ 14      ┆ 68   ┆ 0.615084 ┆ [-0.008502, ┆ … ┆ [0.149554,  ┆ 0.410892   ┆ 0.805705   ┆ 0.652952   │
# │         ┆      ┆          ┆ 0.016859, … ┆   ┆ 6.002989]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.008…     ┆   ┆             ┆            ┆            ┆            │
# └─────────┴──────┴──────────┴─────────────┴───┴─────────────┴────────────┴────────────┴────────────┘

# %%
fig, ax = topol_model.visualize(label_col="random_label")
fig.savefig(os.path.join(OUTPUTS_PATH, f"{FILES_PREFIX}_random_cb_topol_clusters.pdf"), format="pdf", bbox_inches='tight')
plt.show(fig, ax)
# Out:
# Drift computed successfully, ready to visualize.

# %% [markdown]
# ### Drift analysis

# %%
assert cb0_cluster_info["cluster"].to_list() == cb1_cluster_info["cluster"].to_list(), "Cluster IDs are not the same for C.B.-0 and C.B.-1"
clusters = cb0_cluster_info["cluster"].to_list()

# %%
drifts_default = {}
for cluster_id, cb0_centroid, cb1_centroid in zip(clusters, cb0_cluster_info["centroid"].to_list(), cb1_cluster_info["centroid"].to_list()):
    drifts_default[cluster_id] = np.array(cb1_centroid) - np.array(cb0_centroid)

# %%
drifts_random_cb = {}
for cluster_id, cb0_centroid, cb1_centroid in zip(clusters, random_cb0_cluster_info["centroid"].to_list(), random_cb1_cluster_info["centroid"].to_list()):
    drifts_random_cb[cluster_id] = np.array(cb1_centroid) - np.array(cb0_centroid)

# %%
drift_similarities = {}
for cluster_id in clusters:
    drift_default = drifts_default[cluster_id]
    drift_random = drifts_random_cb[cluster_id]
    norm_ratio = np.linalg.norm(drift_default) / np.linalg.norm(drift_random)
    similarity = cosine_similarity([drift_default], [drift_random])[0][0]
    dot_prod = np.dot(drift_default, drift_random)
    drift_similarities[cluster_id] = {
        "cosine_similarity": similarity,
        "dot_product": dot_prod,
        "norm_ratio": norm_ratio
    }
pd.DataFrame(drift_similarities).T
# Out:
#     cosine_similarity  dot_product  norm_ratio
# 0           -0.220596    -0.003040    7.302409
# 1           -0.283284    -0.004554    7.358306
# 2           -0.157106    -0.002458    6.456352
# 3            0.384767     0.007629    5.398008
# 4           -0.313992    -0.005962    5.140033
# 5            0.030381     0.000395    4.167843
# 6            0.206370     0.003033    4.352274
# 7            0.133967     0.002363    6.028456
# 8            0.389193     0.009441    3.978628
# 9           -0.114009    -0.003343    3.469382
# 10          -0.230900    -0.008142    3.220391
# 11           0.233564     0.008083    2.705853
# 12          -0.082075    -0.003848    2.671554
# 13          -0.305122    -0.020694    3.933714
# 14          -0.008668    -0.000476    2.923308

# %%
norm_ratios = [drift_similarities[cluster_id]["norm_ratio"] for cluster_id in clusters]
plt.figure(figsize=(10, 5))
plt.bar(clusters, norm_ratios, color='blue', alpha=0.7)
plt.xlabel('Cluster ID')
plt.ylabel('Norm Ratio')
plt.title('Norm Ratios of Drifts for Each Cluster')
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.75)
# plt.savefig(os.path.join(OUTPUTS_PATH, f"{FILES_PREFIX}_norm_ratios.pdf"), format="pdf", bbox_inches='tight')
print(np.mean(norm_ratios), np.std(norm_ratios))
plt.show()
# Out:
# 4.60710072455448 1.5427955824342992

# %%
# Norm ratio entropy
norm_ratios = np.array(norm_ratios)
norm_ratios = norm_ratios / np.sum(norm_ratios)
norm_ratio_entropy = -np.sum(norm_ratios * np.log(norm_ratios + 1e-10)) / np.log(len(norm_ratios))  # Adding a small value to avoid log(0) and normalizing by log(len(norm_ratios))
print(f"Norm Ratio Entropy: {norm_ratio_entropy}")
# Out:
# Norm Ratio Entropy: 0.9797300372984454

# %% [markdown]
# ### Quality metrics

# %%
cb0_cluster_info[["size", "avg_prob", "cosine_dispersion", "l2_dispersion", "dot_product_dispersion"]].mean()
# Out:
# shape: (1, 5)
# ┌────────────┬──────────┬───────────────────┬───────────────┬────────────────────────┐
# │ size       ┆ avg_prob ┆ cosine_dispersion ┆ l2_dispersion ┆ dot_product_dispersion │
# │ ---        ┆ ---      ┆ ---               ┆ ---           ┆ ---                    │
# │ f64        ┆ f64      ┆ f64               ┆ f64           ┆ f64                    │
# ╞════════════╪══════════╪═══════════════════╪═══════════════╪════════════════════════╡
# │ 333.333333 ┆ 0.651539 ┆ 0.43098           ┆ 0.818864      ┆ 0.674625               │
# └────────────┴──────────┴───────────────────┴───────────────┴────────────────────────┘

# %%
random_cb0_cluster_info[["size", "avg_prob", "cosine_dispersion", "l2_dispersion", "dot_product_dispersion"]].mean()
# Out:
# shape: (1, 5)
# ┌────────────┬──────────┬───────────────────┬───────────────┬────────────────────────┐
# │ size       ┆ avg_prob ┆ cosine_dispersion ┆ l2_dispersion ┆ dot_product_dispersion │
# │ ---        ┆ ---      ┆ ---               ┆ ---           ┆ ---                    │
# │ f64        ┆ f64      ┆ f64               ┆ f64           ┆ f64                    │
# ╞════════════╪══════════╪═══════════════════╪═══════════════╪════════════════════════╡
# │ 333.333333 ┆ 0.682796 ┆ 0.467192          ┆ 0.843722      ┆ 0.714931               │
# └────────────┴──────────┴───────────────────┴───────────────┴────────────────────────┘

# %%
cb1_cluster_info[["size", "avg_prob", "cosine_dispersion", "l2_dispersion", "dot_product_dispersion"]].mean()
# Out:
# shape: (1, 5)
# ┌────────────┬──────────┬───────────────────┬───────────────┬────────────────────────┐
# │ size       ┆ avg_prob ┆ cosine_dispersion ┆ l2_dispersion ┆ dot_product_dispersion │
# │ ---        ┆ ---      ┆ ---               ┆ ---           ┆ ---                    │
# │ f64        ┆ f64      ┆ f64               ┆ f64           ┆ f64                    │
# ╞════════════╪══════════╪═══════════════════╪═══════════════╪════════════════════════╡
# │ 333.333333 ┆ 0.670891 ┆ 0.465025          ┆ 0.842603      ┆ 0.71283                │
# └────────────┴──────────┴───────────────────┴───────────────┴────────────────────────┘

# %%
random_cb1_cluster_info[["size", "avg_prob", "cosine_dispersion", "l2_dispersion", "dot_product_dispersion"]].mean()
# Out:
# shape: (1, 5)
# ┌────────────┬──────────┬───────────────────┬───────────────┬────────────────────────┐
# │ size       ┆ avg_prob ┆ cosine_dispersion ┆ l2_dispersion ┆ dot_product_dispersion │
# │ ---        ┆ ---      ┆ ---               ┆ ---           ┆ ---                    │
# │ f64        ┆ f64      ┆ f64               ┆ f64           ┆ f64                    │
# ╞════════════╪══════════╪═══════════════════╪═══════════════╪════════════════════════╡
# │ 333.333333 ┆ 0.683847 ┆ 0.462989          ┆ 0.841099      ┆ 0.710447               │
# └────────────┴──────────┴───────────────────┴───────────────┴────────────────────────┘

# %% [markdown]
# ### Drift explainability

# %%
XAI_OUTPUTS_PATH = os.path.join(OUTPUTS_PATH, "explainability")

# %% [markdown]
# ##### NRC-VAD Clusters based analysis

# %%
XAI1_PATH = os.path.join(XAI_OUTPUTS_PATH, "nrc_vad_clusters")

# %%
version = "v2.1"  # "v1.0" or "v2.1"
fbase = "NRC-VAD-Lexicon-" + version

nrc_vad_df_path = os.path.join(DATA_PATH, fbase, f"nrc_vad_lexicon_{version}.pkl")
if os.path.exists(nrc_vad_df_path):
    print(f"Loading NRC-VAD lexicon from {nrc_vad_df_path}")
    nrc_vad_df = pd.read_pickle(nrc_vad_df_path) # Pandas DataFrame
else:
    print("File not found.")

nrc_vad_df = pl.DataFrame(nrc_vad_df)
# Out:
# Loading NRC-VAD lexicon from /Users/tig1/Programming/TOPOL/data/NRC-VAD-Lexicon-v2.1/nrc_vad_lexicon_v2.1.pkl

# %%
nrc_vad_embeddings = np.stack(nrc_vad_df["embedding"].to_numpy())
nrc_vad_graph = topol_model.umap_graph.transform(nrc_vad_embeddings)
nrc_vad_adjacency_matrix = csr_matrix(nrc_vad_graph)
nrc_vad_reduced_embeddings = topol_model.umap_dim_reducer.transform(nrc_vad_embeddings)

leiden = Leiden(resolution=2.0, modularity='dugue', random_state=RANDOM_STATE)
leiden.fit(nrc_vad_adjacency_matrix)
nrc_vad_labels = leiden.fit_predict(nrc_vad_adjacency_matrix)
nrc_vad_probs = [probs[cluster_id] for cluster_id, probs in zip(nrc_vad_labels, leiden.predict_proba(False))]

nrc_vad_df = nrc_vad_df.with_columns(
    pl.Series("reduced_embedding", nrc_vad_reduced_embeddings.tolist()),
    pl.Series("cluster", nrc_vad_labels),
    pl.Series("cluster_prob", nrc_vad_probs),
)

# %%
nrcvad_cluster_info = (
    nrc_vad_df.group_by("cluster")
    .map_groups(lambda group: pl.DataFrame({
        "cluster": group["cluster"][0],
        "avg_prob": [np.mean(group["cluster_prob"].to_list())],
        "cluster_size": group.height,
        "terms": [group["term"]],
        "centroid": [np.mean(group["embedding"].to_list(), axis=0)],
        "reduced_centroid": [np.mean(group["reduced_embedding"].to_list(), axis=0)],
        "avg_valence": group["valence"].mean(),
        "avg_arousal": group["arousal"].mean(),
        "avg_dominance": group["dominance"].mean(),
    }))
)
nrcvad_cluster_info = nrcvad_cluster_info.sort("cluster")

# %%
nrcvad_centroids = np.stack(nrcvad_cluster_info["centroid"].to_numpy())
nrcvad_centroids.shape
# Out:
# (26, 1536)

# %% [markdown]
# HoTL proposed contextual boundary

# %%
closest_nrc_vad_cluster_ids = []
valence_values = []
arousal_values = []
dominance_values = []
for row in cb0_cluster_info.iter_rows(named=True):
    centroid = row["centroid"]
    similarities = cosine_similarity([centroid], nrcvad_centroids)[0]
    closest_nrc_vad_cluster_id = int(np.argmax(similarities))
    closest_nrc_vad_cluster_ids.append(closest_nrc_vad_cluster_id)
    nrc_vad_row = nrcvad_cluster_info.filter(pl.col("cluster") == closest_nrc_vad_cluster_id).to_pandas().iloc[0]
    valence_values.append(nrc_vad_row["avg_valence"])
    arousal_values.append(nrc_vad_row["avg_arousal"])
    dominance_values.append(nrc_vad_row["avg_dominance"])

cb0_cluster_info = cb0_cluster_info.with_columns(
    pl.Series("closest_nrc_vad_cluster_id", closest_nrc_vad_cluster_ids),
    pl.Series("valence", valence_values, dtype=pl.Float64),
    pl.Series("arousal", arousal_values, dtype=pl.Float64),
    pl.Series("dominance", dominance_values, dtype=pl.Float64)
)

# %%
closest_nrc_vad_cluster_ids = []
valence_values = []
arousal_values = []
dominance_values = []
for row in cb1_cluster_info.iter_rows(named=True):
    centroid = row["centroid"]
    similarities = cosine_similarity([centroid], nrcvad_centroids)[0]
    closest_nrc_vad_cluster_id = int(np.argmax(similarities))
    closest_nrc_vad_cluster_ids.append(closest_nrc_vad_cluster_id)
    nrc_vad_row = nrcvad_cluster_info.filter(pl.col("cluster") == closest_nrc_vad_cluster_id).to_pandas().iloc[0]
    valence_values.append(nrc_vad_row["avg_valence"])
    arousal_values.append(nrc_vad_row["avg_arousal"])
    dominance_values.append(nrc_vad_row["avg_dominance"])

cb1_cluster_info = cb1_cluster_info.with_columns(
    pl.Series("closest_nrc_vad_cluster_id", closest_nrc_vad_cluster_ids),
    pl.Series("valence", valence_values, dtype=pl.Float64),
    pl.Series("arousal", arousal_values, dtype=pl.Float64),
    pl.Series("dominance", dominance_values, dtype=pl.Float64)
)

# %%
cb0_cluster_info[["valence", "arousal", "dominance"]].mean()
# Out:
# shape: (1, 3)
# ┌───────────┬──────────┬───────────┐
# │ valence   ┆ arousal  ┆ dominance │
# │ ---       ┆ ---      ┆ ---       │
# │ f64       ┆ f64      ┆ f64       │
# ╞═══════════╪══════════╪═══════════╡
# │ -0.187801 ┆ 0.004013 ┆ -0.100733 │
# └───────────┴──────────┴───────────┘

# %%
cb1_cluster_info[["valence", "arousal", "dominance"]].mean()
# Out:
# shape: (1, 3)
# ┌──────────┬──────────┬───────────┐
# │ valence  ┆ arousal  ┆ dominance │
# │ ---      ┆ ---      ┆ ---       │
# │ f64      ┆ f64      ┆ f64       │
# ╞══════════╪══════════╪═══════════╡
# │ 0.082366 ┆ 0.025907 ┆ 0.032316  │
# └──────────┴──────────┴───────────┘

# %%
(cb1_cluster_info[["valence", "arousal", "dominance"]] - cb0_cluster_info[["valence", "arousal", "dominance"]]).to_pandas().plot()
# Out:
# <Axes: >

# %%
cb0_cluster_info["closest_nrc_vad_cluster_id"].unique().to_list(), cb1_cluster_info["closest_nrc_vad_cluster_id"].unique().to_list()
# Out:
# ([0, 3, 4, 5, 11, 13, 15, 18, 24], [0, 1, 3, 8, 9, 11, 13, 15, 16, 18, 19, 24])

# %% [markdown]
# Random contextual boundary

# %%
closest_nrc_vad_cluster_ids = []
valence_values = []
arousal_values = []
dominance_values = []
for row in random_cb0_cluster_info.iter_rows(named=True):
    centroid = row["centroid"]
    similarities = cosine_similarity([centroid], nrcvad_centroids)[0]
    closest_nrc_vad_cluster_id = int(np.argmax(similarities))
    closest_nrc_vad_cluster_ids.append(closest_nrc_vad_cluster_id)
    nrc_vad_row = nrcvad_cluster_info.filter(pl.col("cluster") == closest_nrc_vad_cluster_id).to_pandas().iloc[0]
    valence_values.append(nrc_vad_row["avg_valence"])
    arousal_values.append(nrc_vad_row["avg_arousal"])
    dominance_values.append(nrc_vad_row["avg_dominance"])

random_cb0_cluster_info = random_cb0_cluster_info.with_columns(
    pl.Series("closest_nrc_vad_cluster_id", closest_nrc_vad_cluster_ids),
    pl.Series("valence", valence_values, dtype=pl.Float64),
    pl.Series("arousal", arousal_values, dtype=pl.Float64),
    pl.Series("dominance", dominance_values, dtype=pl.Float64)
)

# %%
closest_nrc_vad_cluster_ids = []
valence_values = []
arousal_values = []
dominance_values = []
for row in random_cb1_cluster_info.iter_rows(named=True):
    centroid = row["centroid"]
    similarities = cosine_similarity([centroid], nrcvad_centroids)[0]
    closest_nrc_vad_cluster_id = int(np.argmax(similarities))
    closest_nrc_vad_cluster_ids.append(closest_nrc_vad_cluster_id)
    nrc_vad_row = nrcvad_cluster_info.filter(pl.col("cluster") == closest_nrc_vad_cluster_id).to_pandas().iloc[0]
    valence_values.append(nrc_vad_row["avg_valence"])
    arousal_values.append(nrc_vad_row["avg_arousal"])
    dominance_values.append(nrc_vad_row["avg_dominance"])

random_cb1_cluster_info = random_cb1_cluster_info.with_columns(
    pl.Series("closest_nrc_vad_cluster_id", closest_nrc_vad_cluster_ids),
    pl.Series("valence", valence_values, dtype=pl.Float64),
    pl.Series("arousal", arousal_values, dtype=pl.Float64),
    pl.Series("dominance", dominance_values, dtype=pl.Float64)
)

# %%
random_cb0_cluster_info[["valence", "arousal", "dominance"]].mean()
# Out:
# shape: (1, 3)
# ┌─────────┬──────────┬───────────┐
# │ valence ┆ arousal  ┆ dominance │
# │ ---     ┆ ---      ┆ ---       │
# │ f64     ┆ f64      ┆ f64       │
# ╞═════════╪══════════╪═══════════╡
# │ 0.04613 ┆ 0.032974 ┆ 0.033562  │
# └─────────┴──────────┴───────────┘

# %%
random_cb1_cluster_info[["valence", "arousal", "dominance"]].mean()
# Out:
# shape: (1, 3)
# ┌─────────┬──────────┬───────────┐
# │ valence ┆ arousal  ┆ dominance │
# │ ---     ┆ ---      ┆ ---       │
# │ f64     ┆ f64      ┆ f64       │
# ╞═════════╪══════════╪═══════════╡
# │ 0.04613 ┆ 0.032974 ┆ 0.033562  │
# └─────────┴──────────┴───────────┘

# %%
(random_cb1_cluster_info[["valence", "arousal", "dominance"]] - random_cb0_cluster_info[["valence", "arousal", "dominance"]]).to_pandas().plot()
# Out:
# <Axes: >

# %%
random_cb0_cluster_info["closest_nrc_vad_cluster_id"].unique().to_list(), random_cb1_cluster_info["closest_nrc_vad_cluster_id"].unique().to_list()
# Out:
# ([0, 1, 3, 5, 8, 9, 11, 13, 15, 16, 18, 22, 24],
#  [0, 1, 3, 5, 8, 9, 11, 13, 15, 16, 18, 22, 24])

# %% [markdown]
# ##### LLM-Generated Approach

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 assert False
#
# AssertionError:

# %%
XAI2_PATH = os.path.join(XAI_OUTPUTS_PATH, "llm_generated")

# %%
fpath = os.path.join(DATA_PATH, "prompt_template.txt")
if os.path.exists(fpath):
    with open(fpath, "r") as f:
        PROMPT_TEMPLATE = f.read()
    print(f"Loaded prompt template from {fpath}")
else:
    raise FileNotFoundError(f"Prompt template file not found at {fpath}")
del fpath
# Out:
# Loaded prompt template from /Users/tig1/Programming/TOPOL/data/prompt_template.txt

# %%
def generate_narrative_comparison_prompt(text1, text2):
    prompt = PROMPT_TEMPLATE.replace("#####TEXT1#####", text1)
    prompt = prompt.replace("#####TEXT2#####", text2)
    return prompt

# %%
# chat_completion_func, model_name = openai_chat_completion, "gpt-4o-mini-2024-07-18"
chat_completion_func, model_name = google_chat_completion, "gemini-2.0-flash"

text_generation_params = {
    "model": model_name,
    "temperature": 0.1,
    "top_p": 1.0,
    # "presence_penalty": 0.0,
    # "frequency_penalty": 0.0,
    "max_tokens": 1000000,
}

K = 5  # Number of top documents to retrieve for each cluster

# %% [markdown]
# HoTL proposed contextual boundary

# %%
cb0_df = topol_model.df.filter(pl.col("label") == 0).clone()
top_k_docs = get_top_k_representative_docs(cb0_cluster_info, cb0_df, k=K)
cb0_cluster_info = cb0_cluster_info.join(top_k_docs, on="cluster", how="left")

# %%
cb1_df = topol_model.df.filter(pl.col("label") == 1).clone()
top_k_docs = get_top_k_representative_docs(cb1_cluster_info, cb1_df, k=K)
cb1_cluster_info = cb1_cluster_info.join(top_k_docs, on="cluster", how="left")

# %%
for cluster_id in tqdm(clusters, desc="Processing clusters"):
    cb0_row = cb0_cluster_info.filter(pl.col("cluster") == cluster_id).to_dicts()[0]
    cb1_row = cb1_cluster_info.filter(pl.col("cluster") == cluster_id).to_dicts()[0]

    # Generate the prompt for the LLM
    text1 = from_list_to_string(cb0_row["top_docs"])
    text2 = from_list_to_string(cb1_row["top_docs"])
    prompt = generate_narrative_comparison_prompt(text1, text2)
    response = chat_completion_func(prompt, **text_generation_params)

    # Parse the JSON response safely
    parsed_llm_out = safe_json_load(response)

    # Save to file
    fname = f"{FILES_PREFIX}_HoTL_cluster_{cluster_id}.json"
    fpath = os.path.join(XAI2_PATH, fname)
    with open(fpath, "w", encoding="utf-8") as f:
        json.dump(parsed_llm_out, f, ensure_ascii=False, indent=2)
# Out:
# Processing clusters:   0%|          | 0/15 [00:00<?, ?it/s]
# Response: ```json
# [
#   {
#     "dimension_title": "Disappointment to Appreciation",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "Very disappointing to me I am a very, very big Elliott Smith fan and have been for DATE, the kind who has every recording, live, bootleg, videos of him playing, saw him live, read his biography, etc.",
#       "I am selling my copy of this album without even ripping it because there isn't a single song on it that does anything new with the music or is in any way better than the originals."
#     ],
#     "text2_evidence_sentences": [
#       "Like any treasure, must be heard to be appreciated.",
#       "I was pleasantly surprised, though, with the rest of the work."
#     ],
#     "text1_keywords": ["disappointing", "Waste of time, waste of money"],
#     "text2_keywords": ["treasure", "pleasantly surprised"]
#   },
#   {
#     "dimension_title": "Harsh Criticism to Enthusiastic Recommendation",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "I wish there was the zero star option This album does not even deserve the praise of one mesely star.",
#       "Don't buy this CD, please for your mind's sake."
#     ],
#     "text2_evidence_sentences": [
#       "This is one of those rare albums that each and every single song on there is absolutely amazing.",
#       "This is a brilliant album, and a brilliant artist."
#     ],
#     "text1_keywords": ["does not even deserve", "awful"],
#     "text2_keywords": ["absolutely amazing", "brilliant"]
#   },
#   {
#     "dimension_title": "Negative Judgment to Positive Reception",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "What a waste of hard earned cash!!!",
#       "SOOOooo incredibly boring..."
#     ],
#     "text2_evidence_sentences": [
#       "I just brouth the cd DATE and i have played it non-stop since i got it.",
#       "I decided this CD and im damn sure happy i did."
#     ],
#     "text1_keywords": ["waste", "lack of imagination"],
#     "text2_keywords": ["non-stop", "happy"]
#   }
# ]
# ```
# Tokens used: 3596
# Cost of the request: $0.000007
# Response: ```json
# [
#   {
#     "dimension_title": "Disappointment to Appreciation",
#     "text1_sentence_count": 3,
#     "text2_sentence_count": 3,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 60,
#     "confidence_score_text2": 60,
#     "text1_evidence_sentences": [
#       "I Can't Believe I Watched the Whole Thing Definitely the absolute WORST movie I have ever seen.",
#       "Well, that was terrible... I'm disapointed that I'm never getting back TIME of my life I wasted on watching \"The Descent.\"",
#       "Mindless and unoriginal I must say that after having watched this I was offended that a friend had recommended it to me."
#     ],
#     "text2_evidence_sentences": [
#       "Great Movie This is possibly one of the best movies I've seen in a long time - I really appreciated the movie's theme.",
#       "Love this movie!!!! I watched this movie over DATE, and I really loved it!",
#       "Wonderful DATE movie! This move is full of all kinds of emotions and issues but still makes you feel good."
#     ],
#     "text1_keywords": ["WORST movie", "terrible", "offended"],
#     "text2_keywords": ["best movies", "loved it", "feel good"]
#   },
#   {
#     "dimension_title": "Frustration to Enjoyment",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "Completely boring, no plot, nothing interesting.",
#       "There is so much talking about crap no one cares about and robert trying to make the audience laugh with his corny boring jokes and its very long too so get ready to kill yourself at the end"
#     ],
#     "text2_evidence_sentences": [
#       "Tons of great content I don't know of anything else quite like this DVD. I have had it for DATE now, and still have not seen everything it has to offer, and all of it is so good.",
#       "It is has drama, comedy, incredible music and choral singing, great acting and cinematography, enough realism to avoid being a saccharine fairy tale, and a minor surprise ending to remind us that amid all the tragedy, ruthlessness, and sorrow in life, we can still hope that good will win out!"
#     ],
#     "text1_keywords": ["boring", "crap no one cares about"],
#     "text2_keywords": ["great content", "comedy"]
#   },
#   {
#     "dimension_title": "Nonsense to Meaningfulness",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "And what did the stupid rabbit head scenes have to do with anything? For that matter what did any of the movie have to do with anything? It made absolutely NO sense.",
#       "What the hell did I just watch."
#     ],
#     "text2_evidence_sentences": [
#       "I really appreciated the movie's theme.",
#       "There was a part where I even cried, this movie touches your heart and is something the entire family can watch."
#     ],
#     "text1_keywords": ["NO sense", "What the hell"],
#     "text2_keywords": ["movie's theme", "touches your heart"]
#   }
# ]
# ```
# Tokens used: 3395
# Cost of the request: $0.000007
# Response: ```json
# [
#   {
#     "dimension_title": "Critical to Enthusiastic",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 3,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 60,
#     "text1_evidence_sentences": [
#       "Sadly, I found the characters to be very shallow and too cheerful.",
#       "Falls between two chairs If \"The Secret of Chimneys\" was supposed to be a comedy, it's not funny enough; and if it was supposed to be a thriller, it's not tense and dramatic and mysterious enough."
#     ],
#     "text2_evidence_sentences": [
#       "IT WAS GREAT!!!",
#       "This book rekindled my love for reading!!!",
#       "wow Im DATE and I found this book to be awesome It touched me in a way I cant even begin to explain it was excellent full of secrets lost loves and lost lives anyone who loves a good book should read it."
#     ],
#     "text1_keywords": ["shallow", "not funny enough", "not tense and dramatic"],
#     "text2_keywords": ["GREAT", "love for reading", "awesome", "excellent"]
#   },
#   {
#     "dimension_title": "Disappointment to Satisfaction",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "Shallow, disappointing I understand that children love these books and love mysteries.",
#       "A curiosity more than anything else."
#     ],
#     "text2_evidence_sentences": [
#       "Pleasant Read! What a breath of fresh air this book was to read.",
#       "It left the reader very satisfied."
#     ],
#     "text1_keywords": ["disappointing", "shallow", "curiosity"],
#     "text2_keywords": ["Pleasant Read", "fresh air", "satisfied"]
#   }
# ]
# ```
# Tokens used: 2977
# Cost of the request: $0.000006
# Response: ```json
# [
#   {
#     "dimension_title": "Disappointment to Satisfaction",
#     "text1_sentence_count": 3,
#     "text2_sentence_count": 3,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 60,
#     "confidence_score_text2": 60,
#     "text1_evidence_sentences": [
#       "Very poor quality.",
#       "Nice try Belkin, come back when you have a product that works.",
#       "Very disappointed since the price was so high."
#     ],
#     "text2_evidence_sentences": [
#       "I absolutely love this product.",
#       "Excellent product, flawless service I give this product NUM stars, simply because it performs better than expectations",
#       "Worth the money!"
#     ],
#     "text1_keywords": ["worthless", "total junk", "waste of money"],
#     "text2_keywords": ["almost perfect", "slick", "pretty decent"]
#   },
#   {
#     "dimension_title": "Frustration to Enjoyment",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "I've wasted so much time and gone through some humility trying to fix this!!",
#       "Also, it was never very easy to use and the disc cover popped open very easily."
#     ],
#     "text2_evidence_sentences": [
#       "Techno gadgets are cool - tuning in XM stations on my receiver rates up there in \"cool category\".",
#       "It is fun. ;-)"
#     ],
#     "text1_keywords": ["fix this", "never very easy to use", "humility"],
#     "text2_keywords": ["cool", "fun", "enjoyment"]
#   }
# ]
# ```
# Tokens used: 2693
# Cost of the request: $0.000005
# Response: ```json
# [
#   {
#     "dimension_title": "Disappointment to Enjoyment",
#     "text1_sentence_count": 4,
#     "text2_sentence_count": 4,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 80,
#     "confidence_score_text2": 80,
#     "text1_evidence_sentences": [
#       "Very Disappointing I'm not sure where to start- from the painfully irrelevant details to the totally unrealistic murder description, this book was a waste of time.",
#       "Once again I feel the sting of having read a book, studying each line, reading each word...only to be disappointed.",
#       "However, upon reading it I was more disappointed than delighted.",
#       "'Disappointment is an understatement' 'Disapointment'is an understatement for this book which is, in my DATE of reading, possibly the most awful thing I've read."
#     ],
#     "text2_evidence_sentences": [
#       "I can recommend this book as a very enjoyable read, and quite good for young readers, but it seems clear a big, fat, long, unimpeachably correct bio would make a lot of other people happy.",
#       "Very hard to put down and a very satisfying read!",
#       "I really enjoyed most of book... but it had an awkward pace.",
#       "Others like me who are not so worried will find this an easy and entertaining read that will leave you feeling a trifle sad about the world she has created in this novel."
#     ],
#     "text1_keywords": ["Disappointing", "waste of time", "disappointed", "awful thing"],
#     "text2_keywords": ["enjoyable read", "satisfying read", "enjoyed", "entertaining read"]
#   },
#   {
#     "dimension_title": "Criticism to Appreciation",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "The concept of the book sounded good but the execution was terrible.",
#       "It leaves you unfulfilled, depressed, and somewhat confused."
#     ],
#     "text2_evidence_sentences": [
#       "I think that the majority of these negative reviews come from readers who can't appreciate a novel from a truly artistic point of view.",
#       "CB is full of wonderful detail and exquisite storytelling."
#     ],
#     "text1_keywords": ["execution was terrible", "unfulfilled", "confused"],
#     "text2_keywords": ["appreciate", "wonderful detail", "storytelling"]
#   }
# ]
# ```
# Tokens used: 3206
# Cost of the request: $0.000006
# Response: ```json
# [
#   {
#     "dimension_title": "Disappointment to Satisfaction",
#     "text1_sentence_count": 3,
#     "text2_sentence_count": 3,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 60,
#     "confidence_score_text2": 60,
#     "text1_evidence_sentences": [
#       "This book was a big let down.",
#       "I wish I could return this book.",
#       "This book was not interesting, not worth my time, not worth the money."
#     ],
#     "text2_evidence_sentences": [
#       "My photographs look better and I feel like I really know what I'm doing instead of counting on my camera to do all of the work.",
#       "This section makes the book a worthwhile buy.",
#       "This Book Really helped."
#     ],
#     "text1_keywords": ["big let down", "return this book", "not worth"],
#     "text2_keywords": ["look better", "worthwhile buy", "Really helped"]
#   },
#   {
#     "dimension_title": "Uselessness to Usefulness",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "After going through this book, I can find nothing useful.",
#       "This book is a complete waste."
#     ],
#     "text2_evidence_sentences": [
#       "this book has been a tremendous help in teaching me techniques to use.",
#       "the book enables you to view and intrigue yourself with many different techniques."
#     ],
#     "text1_keywords": ["nothing useful", "complete waste"],
#     "text2_keywords": ["tremendous help", "different techniques"]
#   },
#   {
#     "dimension_title": "Complexity to Clarity",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "In this book the author just gives you a bunch of disassociated illustrations.",
#       "Included are picture that supposedly illustrate the book's points; the only problem being that most pictures are so dark and unhelpful that they only serve as additional filler to turn this flimsy piece into book length."
#     ],
#     "text2_evidence_sentences": [
#       "Easy to read and best of all - it all makes sense.",
#       "Thanks for writing such a great book that is easy to understand."
#     ],
#     "text1_keywords": ["disassociated illustrations", "dark and unhelpful"],
#     "text2_keywords": ["Easy to read", "easy to understand"]
#   }
# ]
# ```
# Tokens used: 2883
# Cost of the request: $0.000006
# Response: ```json
# [
#   {
#     "dimension_title": "Disappointment to Satisfaction",
#     "text1_sentence_count": 3,
#     "text2_sentence_count": 3,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 60,
#     "confidence_score_text2": 60,
#     "text1_evidence_sentences": [
#       "I just wasted $NUM of my hard earned money.",
#       "Overall, this item is not worth buying which is really disappointing because the concept is outstanding.",
#       "Waste of money Not that it cost very much, but a waste nonetheless."
#     ],
#     "text2_evidence_sentences": [
#       "That early disappointment turned into pure joy for her because she LOVED this!",
#       "They are bright, attractive and easy to play with.",
#       "Very happy with this jumperoo!"
#     ],
#     "text1_keywords": ["wasted my money", "not worth buying", "disappointing"],
#     "text2_keywords": ["pure joy", "easy to play with", "happy"]
#   },
#   {
#     "dimension_title": "Durability Concerns to Enduring Quality",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "made very cheaply and it reflects.",
#       "I thought this would be durable and my daughter had to keep putting the parts back on all the time she said forget she had enough!"
#     ],
#     "text2_evidence_sentences": [
#       "The mat and pom-poms have held up well (my younger daughter broke tne batan) and the dvd, although a little fast paced, has not deterred my daughter at all!",
#       "It holds up wonderfully, wipes clean easily, and has lots to entertain kids."
#     ],
#     "text1_keywords": ["made very cheaply", "parts constantly falling off"],
#     "text2_keywords": ["held up well", "holds up wonderfully"]
#   }
# ]
# ```
# Tokens used: 2816
# Cost of the request: $0.000006
# Response: ```json
# [
#   {
#     "dimension_title": "Disappointment to Satisfaction",
#     "text1_sentence_count": 3,
#     "text2_sentence_count": 3,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 60,
#     "confidence_score_text2": 60,
#     "text1_evidence_sentences": [
#       "I was so excited to see this product on Amazon only to be greatly disappointed.",
#       "The concept is great, the execution is poor.",
#       "I really wanted to love this thing."
#     ],
#     "text2_evidence_sentences": [
#       "I works as advertised!",
#       "The knife seems to be just what I needed for my level of cooking.",
#       "Its a simple but effective products, no whistles and pipes."
#     ],
#     "text1_keywords": ["disappointment", "poor", "wanted to love"],
#     "text2_keywords": ["as advertised", "what I needed", "effective"]
#   },
#   {
#     "dimension_title": "Short Lifespan to Durability",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "but after DATE it BREAKS!!",
#       "This thing grinded enough for a total of NUM espresso's at fine setting."
#     ],
#     "text2_evidence_sentences": [
#       "sturdily constructed, it seems it will last a very, very long time.",
#       "i loved it so much i wore it out, and got another one in DATE and i have worn it out also, i am starting on my third one"
#     ],
#     "text1_keywords": ["BREAKS", "stopped"],
#     "text2_keywords": ["long time", "wore it out"]
#   },
#   {
#     "dimension_title": "Unreliability to Reliability",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "For no reason at all one day it started to leak a ton of water while brewing and was unfixable.",
#       "The fact that the system died on me TIME by the simple virtue of it getting wet negates all the coplementary remarks I just made."
#     ],
#     "text2_evidence_sentences": [
#       "It keeps a decent edge, and a small touch up with my steel keeps it sharp.",
#       "They've been working great for her so far."
#     ],
#     "text1_keywords": ["unfixable", "died on me"],
#     "text2_keywords": ["keeps it sharp", "working great"]
#   }
# ]
# ```
# Tokens used: 3022
# Cost of the request: $0.000006
# Response: ```json
# [
#   {
#     "dimension_title": "Disappointment to Satisfaction",
#     "text1_sentence_count": 3,
#     "text2_sentence_count": 3,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 60,
#     "confidence_score_text2": 60,
#     "text1_evidence_sentences": [
#       "but it DIDN'T, it didn't do a bit, not even the stain from lipsticks, spaghetti spots etc..",
#       "This product is unpleasant.",
#       "I am very disappointed and we finally broke down and bought the Diaper Genie DATE."
#     ],
#     "text2_evidence_sentences": [
#       "what an AMAZING product!",
#       "Amazing! I love this stuff",
#       "I have been using this shampoo for DATE, and I LOVE it."
#     ],
#     "text1_keywords": ["didn't work", "unpleasant", "disappointed"],
#     "text2_keywords": ["AMAZING", "I love this", "LOVE it"]
#   },
#   {
#     "dimension_title": "Ineffectiveness to Effectiveness",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "but it DIDN'T, it didn't do a bit, not even the stain from lipsticks, spaghetti spots etc..",
#       "We have tried EVERYTHING during this time to make this pail work, but it is a failure."
#     ],
#     "text2_evidence_sentences": [
#       "It seems to be helping as I'm not seeing as much hair on my floors and clothes as before.",
#       "Well by DATE she was eating again!"
#     ],
#     "text1_keywords": ["didn't do a bit", "failure"],
#     "text2_keywords": ["helping", "eating again"]
#   },
#   {
#     "dimension_title": "Negative Experience to Positive Experience",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "my hair looked horrible i looked like a witch it made my hair very frizzy",
#       "His room CONSTANTLY stinks of dirty diapers."
#     ],
#     "text2_evidence_sentences": [
#       "Another great part is that it does not irritate private areas (if it accidentally get there) because believe me that is a mood killer!",
#       "Her coat is soft and shiny."
#     ],
#     "text1_keywords": ["horrible", "stinks"],
#     "text2_keywords": ["great", "soft and shiny"]
#   }
# ]
# ```
# Tokens used: 2883
# Cost of the request: $0.000006
# Response: ```json
# [
#   {
#     "dimension_title": "Frustration to Satisfaction",
#     "text1_sentence_count": 3,
#     "text2_sentence_count": 3,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 60,
#     "confidence_score_text2": 60,
#     "text1_evidence_sentences": [
#       "DOES NOT WORK I purchased this product, tried to install it and have ended up frustrated with a non-working product.",
#       "I've been nothing but disappointed with this product.",
#       "Their tech support has \"passed the buck\" and the product just doesn't work."
#     ],
#     "text2_evidence_sentences": [
#       "I am extremely happy with my purchase and look forward to getting many DATE of use out of this camera.",
#       "This is overall a GREAT camera for those who want something better than your average point and shoot but don't want to spend the $ for the SLR.",
#       "Excellent I had had this camera for DATE now and I can't tell you had much I love it."
#     ],
#     "text1_keywords": ["frustrated", "doesn't work", "disappointed"],
#     "text2_keywords": ["happy", "GREAT camera", "love it"]
#   },
#   {
#     "dimension_title": "Unreliability to Reliability",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "Sure, this product works just great... until it breaks!!!",
#       "Now after DATE worth of moderate use, this printer has failed to function...and for the cost of getting it serviced...I would rather replace it with a different machine."
#     ],
#     "text2_evidence_sentences": [
#       "Reliability, I took NUM+ pictures without a single glitch (Raw and JPEG).",
#       "Finally you can put an entire session on a single card."
#     ],
#     "text1_keywords": ["until it breaks", "failed to function"],
#     "text2_keywords": ["without a single glitch", "entire session"]
#   },
#   {
#     "dimension_title": "Complexity to Simplicity",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "The scanner, copier and fax are all cumbersome to use...and the fax never has worked correctly.",
#       "Also, you have to manually open the ScanMaker NUM program and click the scanner control button and then close out of the program to get the light to go off."
#     ],
#     "text2_evidence_sentences": [
#       "It's easy to use, takes good pictures, and yet, if you want to get more complicated, you can do your own settings.",
#       "I found this camera very easy to use right out of the box."
#     ],
#     "text1_keywords": ["cumbersome to use", "manually open"],
#     "text2_keywords": ["easy to use", "easy to navigate"]
#   }
# ]
# ```
# Tokens used: 3402
# Cost of the request: $0.000007
# Response: ```json
# [
#   {
#     "dimension_title": "Frustration to Enthusiasm",
#     "text1_sentence_count": 3,
#     "text2_sentence_count": 3,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 60,
#     "confidence_score_text2": 60,
#     "text1_evidence_sentences": [
#       "WHAT A F---ING WASTE OF MY F---ING MONEY!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!",
#       "I'm really disappointed how lame this \"game\" is.",
#       "I wish I didn't waste $NUM renting this game."
#     ],
#     "text2_evidence_sentences": [
#       "Best \"#@&%;!\" Game Ever !!",
#       "This game is the best game I have ever had!",
#       "Extraordinary game This game is probably the best I've ever played, and perhaps the best game I will ever play."
#     ],
#     "text1_keywords": ["WASTE", "sucks s--t", "lame"],
#     "text2_keywords": ["genius", "AWESOME", "very fun"]
#   },
#   {
#     "dimension_title": "Disappointment to Addiction",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "You would be better off spending your money somewhere else.",
#       "I do not recommend this game to anyone...save your money for something better."
#     ],
#     "text2_evidence_sentences": [
#       "Also, be sure to buy this when you don't have anything to do in DATE, because beware: this game is the most addicting game out on the market, i played this for DATE for TIME a day, and i still play it now, DATE after i bought it, please buy this game if you want to play the very best of ps2 games",
#       "Buy it, you'll like it. trust me."
#     ],
#     "text1_keywords": ["better off spending", "save your money"],
#     "text2_keywords": ["addicting game", "buy this game"]
#   },
#   {
#     "dimension_title": "Rejection to Appreciation",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "wow this...! I am a pretty big gamer. So i would like to think i am not blowing smoke but this game just did not cut it.",
#       "This game isn't even worth the NUM bucks i spent renting it."
#     ],
#     "text2_evidence_sentences": [
#       "I guess what I'm tryin to say is I see nothing wrong with this game, it's one of the best games I have ever played ever.",
#       "This fighter is lots of fun once you learn to handle how to punch, kick and jump (forget the classic Defense-Punch-Kick system)."
#     ],
#     "text1_keywords": ["did not cut it", "not blowing smoke", "not worth"],
#     "text2_keywords": ["nothing wrong", "lots of fun", "love this one"]
#   }
# ]
# ```
# Tokens used: 3695
# Cost of the request: $0.000007
# Response: ```json
# [
#   {
#     "dimension_title": "Frustration to Acceptance",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "Not happy with this purchase at all!!",
#       "I feel royally hipped."
#     ],
#     "text2_evidence_sentences": [
#       "they are good enough, and not every movie I see needs to be digitally remastered quality.",
#       "I highly recommend, and I was very happy with my purchase, its just sad that the bonus features didn't match the quality of the film itself is all I only criticize in hopes that it helps anyone better understand this aspect of their purchase..."
#     ],
#     "text1_keywords": ["Not happy", "royally hipped"],
#     "text2_keywords": ["good enough", "happy with my purchase"]
#   },
#   {
#     "dimension_title": "Emphasis on Technical Flaws to Overall Enjoyment",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "Too many artifacts (blobs of dust) and jerky movements.",
#       "The dvd transfer is absolutely horrible."
#     ],
#     "text2_evidence_sentences": [
#       "I really enjoyed this boxed set.",
#       "Film: Bonuses: Amazing chapter in the evangelion rebuild, a must see and must own for any Eva fan."
#     ],
#     "text1_keywords": ["artifacts", "jerky movements", "horrible transfer"],
#     "text2_keywords": ["enjoyed", "Amazing chapter"]
#   }
# ]
# ```
# Tokens used: 3046
# Cost of the request: $0.000006
# Response: ```json
# [
#   {
#     "dimension_title": "Disappointment to Satisfaction",
#     "text1_sentence_count": 3,
#     "text2_sentence_count": 3,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 60,
#     "confidence_score_text2": 60,
#     "text1_evidence_sentences": [
#       "I am VERY DISATISFIED with my product!!!!!",
#       "I am upset that my daughter missed out on one of her gifts for her 3rd Birthday.",
#       "I am very disappointed when i ordered this i had the color in mind i wanted and boy was i wrong..."
#     ],
#     "text2_evidence_sentences": [
#       "I am very happy with my kindle.",
#       "I really enjoy my new kindle and the ease of reading has been very satisfactory.",
#       "I love the convenience and I am pretty sure that I will never buy a written book again."
#     ],
#     "text1_keywords": ["VERY DISATISFIED", "upset", "disappointed"],
#     "text2_keywords": ["very happy", "really enjoy", "love the convenience"]
#   },
#   {
#     "dimension_title": "Distrust to Endorsement",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "I will NOT be using Amazon, or this seller again.",
#       "I was very dissapionted and will probably shop for this item where I can see it up close since I cannot trust the disciption."
#     ],
#     "text2_evidence_sentences": [
#       "Worth every dollar.",
#       "Would I buy one again? You betcha!"
#     ],
#     "text1_keywords": ["NOT be using", "cannot trust"],
#     "text2_keywords": ["Worth", "You betcha"]
#   },
#   {
#     "dimension_title": "Frustration to Enthusiasm",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "I have since e-mailed them again and I never got a reply.",
#       "I am upset that my daughter missed out on one of her gifts for her 3rd Birthday."
#     ],
#     "text2_evidence_sentences": [
#       "Best gadget I've owned.",
#       "It has done the job of rekindling my reading passion."
#     ],
#     "text1_keywords": ["never got a reply", "upset"],
#     "text2_keywords": ["Best gadget", "reading passion"]
#   }
# ]
# ```
# Tokens used: 2752
# Cost of the request: $0.000006
# Response: ```json
# [
#   {
#     "dimension_title": "Negative Experience to Positive Experience",
#     "text1_sentence_count": 5,
#     "text2_sentence_count": 5,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 100,
#     "confidence_score_text2": 100,
#     "text1_evidence_sentences": [
#       "This band is not great for a smaller wrist.",
#       "the winder is useless and does not wind the watch at all.",
#       "I do not like it.",
#       "Didn't work for either a Timex watch or a Kenneth Cole watch.",
#       "only problem i have with it is that every so often the watch falls off."
#     ],
#     "text2_evidence_sentences": [
#       "Great Just want I wanted.",
#       "Exactly what I wanted The CD case is exactly what I was looking for and the price was unbeatable, even including shipping.",
#       "Great!!! Great experience, as described DATE.",
#       "Just what I wanted !! This was exactly what I wanted & needed.",
#       "I was very pleased with my last purchase!"
#     ],
#     "text1_keywords": ["not great", "useless", "do not like", "Didn't work", "problem"],
#     "text2_keywords": ["Great", "Exactly what I wanted", "Great experience", "very pleased", "very happy"]
#   },
#   {
#     "dimension_title": "Frustration to Satisfaction",
#     "text1_sentence_count": 3,
#     "text2_sentence_count": 3,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 60,
#     "confidence_score_text2": 60,
#     "text1_evidence_sentences": [
#       "The velcro at the end of the strap does not hold tight to the band, and it catches on the cuffs of sweaters and fleeces, making them pill.",
#       "I was trying to change it manually but could not navigate the instructions and ALL the buttons.",
#       "These at on very tight -- also tried (and failed) to open with an oyster knife."
#     ],
#     "text2_evidence_sentences": [
#       "Product was just as I expected.",
#       "it turned out to be a very sturdy and well made product.",
#       "This was exactly what I wanted & needed."
#     ],
#     "text1_keywords": ["does not hold tight", "catches", "could not navigate", "failed"],
#     "text2_keywords": ["just as I expected", "sturdy", "well made", "exactly what I wanted"]
#   }
# ]
# ```
# Tokens used: 2427
# Cost of the request: $0.000005
# Response: ```json
# [
#   {
#     "dimension_title": "Disappointment to Satisfaction",
#     "text1_sentence_count": 3,
#     "text2_sentence_count": 3,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 60,
#     "confidence_score_text2": 60,
#     "text1_evidence_sentences": [
#       "I was looking forward to it but was very disappointed.",
#       "Don't waste your money, you will be disappointed.",
#       "I was so dissappointed!"
#     ],
#     "text2_evidence_sentences": [
#       "I found a clip on youtube and liked what I saw.",
#       "Loved it.",
#       "I always enjoy the workouts that Prevention puts together"
#     ],
#     "text1_keywords": ["very disappointed", "waste your money", "dissappointed"],
#     "text2_keywords": ["liked what I saw", "enjoy", "loved"]
#   },
#   {
#     "dimension_title": "Boredom to Engagement",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "After that it becomes mundane and VERY BORING.",
#       "Beginners WILL get LOST and the more advanced will be BORED."
#     ],
#     "text2_evidence_sentences": [
#       "You actually have fun with this DVD, by the time you realize it you have done TIME.",
#       "It's fun and Karen is an excellent instructor."
#     ],
#     "text1_keywords": ["VERY BORING", "get LOST", "will be BORED"],
#     "text2_keywords": ["have fun", "fun", "enjoy"]
#   },
#   {
#     "dimension_title": "Ineffectiveness to Effectiveness",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "This DVD did not hold my attention and was NOT it a good work out.",
#       "this is not a workout at all - just a seies of dances (very good I admit and fun to do) - no worm up, no cool down"
#     ],
#     "text2_evidence_sentences": [
#       "You will sweat you butt off, I couldn't do all the routines but by my 4th workout I was improving.",
#       "In DATE; NUM sessions I lost NUM IBS. I could not believe it."
#     ],
#     "text1_keywords": ["not a good workout", "not a workout at all", "no cool down"],
#     "text2_keywords": ["lose weight", "sweat", "improving"]
#   }
# ]
# ```
# Tokens used: 3334
# Cost of the request: $0.000007

# %% [markdown]
# Random contextual boundary

# %%
random_cb0_df = topol_model.df.filter(pl.col("random_label") == 0).clone()
top_k_docs = get_top_k_representative_docs(random_cb0_cluster_info, random_cb0_df, k=K)
random_cb0_cluster_info = random_cb0_cluster_info.join(top_k_docs, on="cluster", how="left")

# %%
random_cb1_df = topol_model.df.filter(pl.col("random_label") == 1).clone()
top_k_docs = get_top_k_representative_docs(random_cb1_cluster_info, random_cb1_df, k=K)
random_cb1_cluster_info = random_cb1_cluster_info.join(top_k_docs, on="cluster", how="left")

# %%
for cluster_id in tqdm(clusters, desc="Processing random clusters"):
    cb0_row = random_cb0_cluster_info.filter(pl.col("cluster") == cluster_id).to_dicts()[0]
    cb1_row = random_cb1_cluster_info.filter(pl.col("cluster") == cluster_id).to_dicts()[0]

    # Generate the prompt for the LLM
    text1 = from_list_to_string(cb0_row["top_docs"])
    text2 = from_list_to_string(cb1_row["top_docs"])
    prompt = generate_narrative_comparison_prompt(text1, text2)
    response = chat_completion_func(prompt, **text_generation_params)

    # Parse the JSON response safely
    parsed_llm_out = safe_json_load(response)

    # Save to file
    fname = f"{FILES_PREFIX}_random_cluster_{cluster_id}.json"
    fpath = os.path.join(XAI2_PATH, fname)
    with open(fpath, "w", encoding="utf-8") as f:
        json.dump(parsed_llm_out, f, ensure_ascii=False, indent=2)
# Out:
# Processing random clusters:   0%|          | 0/15 [00:00<?, ?it/s]
# Response: ```json
# [
#   {
#     "dimension_title": "Harsh Criticism to Qualified Appreciation",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "Songs that are plain awful are 'Bomb', 'Testosterone', 'Monkey', and 'Alien'.",
#       "The rest of the CD isn't anything I want to listen to."
#     ],
#     "text2_evidence_sentences": [
#       "OK but not Gods gift.",
#       "About half of this cd is quite good."
#     ],
#     "text1_keywords": ["plain awful", "Steer clear"],
#     "text2_keywords": ["not Gods gift", "quite good"]
#   },
#   {
#     "dimension_title": "Focus on Individual Songs to Album Experience",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "One good song... I ordered this CD based on one song I had heard.",
#       "I will give you what i thought for each song."
#     ],
#     "text2_evidence_sentences": [
#       "This is one of those rare albums that each and every single song on there is absolutely amazing.",
#       "The kind of CD you put in car and enjoy the ride, because each song makes you move and sing along."
#     ],
#     "text1_keywords": ["one song", "each song"],
#     "text2_keywords": ["entire album", "enjoy the ride"]
#   }
# ]
# ```
# Tokens used: 3304
# Cost of the request: $0.000007
# Response: ```json
# [
#   {
#     "dimension_title": "Enthusiasm to Disappointment",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "Tons of great content I don't know of anything else quite like this DVD.",
#       "This DVD is loaded with tons of great content."
#     ],
#     "text2_evidence_sentences": [
#       "Overall, this movie has its moments, but it certainly has earned its criticisms because with the exception of a few rare moments of good wit, this movie would have been a waste of $NUM to buy and only end up watching just once.",
#       "If given a chance to recommend this movie, I would say to keep looking because this movie would be a waste of an evening."
#     ],
#     "text1_keywords": ["great content", "wonderful"],
#     "text2_keywords": ["waste", "critical"]
#   },
#   {
#     "dimension_title": "Tolerance to Rejection",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "I sat down not expecting much from this film but at least expecting something I could smile at every now and then.",
#       "Too bad you can't get a refund on sucky movie rentals."
#     ],
#     "text2_evidence_sentences": [
#       "I actaully shut this one off due to complete bordem which is something I never do.",
#       "This one definately doesn't get my seal of approval."
#     ],
#     "text1_keywords": ["expecting", "sucky"],
#     "text2_keywords": ["shut this one off", "doesn't get my seal of approval"]
#   }
# ]
# ```
# Tokens used: 3372
# Cost of the request: $0.000007
# Response: ```json
# [
#   {
#     "dimension_title": "Enthusiastic Praise to Measured Appreciation",
#     "text1_sentence_count": 3,
#     "text2_sentence_count": 3,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 60,
#     "confidence_score_text2": 60,
#     "text1_evidence_sentences": [
#       "IT WAS GREAT!!!",
#       "This book was truely amazing and i read it in DATE.",
#       "This book rekindled my love for reading!!!"
#     ],
#     "text2_evidence_sentences": [
#       "Interesting characters, good story, absorbing period setting.",
#       "Enough Snap,crackle and Pop for a good novel",
#       "It's an easy read, but very hard to forget."
#     ],
#     "text1_keywords": ["amazing", "love for reading", "GREAT"],
#     "text2_keywords": ["good story", "easy read", "Interesting characters"]
#   },
#   {
#     "dimension_title": "Focus on Entertainment to Focus on Depth",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "Not only was I thoroughly entertained, but I even walked away learning a thing or two about forgiveness.",
#       "The story moved quickly and kept my interest throughout, which is not an easy task."
#     ],
#     "text2_evidence_sentences": [
#       "Unexpected Elegant in it's simplicity, profound in it's depth.",
#       "No short answers here, but easy to grasp concepts that can change lives in the contexts of deep pain and our relationship to a God that never stops loving us."
#     ],
#     "text1_keywords": ["thoroughly entertained", "kept my interest"],
#     "text2_keywords": ["profound in it's depth", "change lives"]
#   }
# ]
# ```
# Tokens used: 2960
# Cost of the request: $0.000006
# Response: ```json
# [
#   {
#     "dimension_title": "Initial Enthusiasm to Eventual Disappointment",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "On a lighter note it worked extremely well while it worked.",
#       "Music was crystal clear, far better than any CD player I have listened to."
#     ],
#     "text2_evidence_sentences": [
#       "As cool and unique as this unit looks.",
#       "The first one was defective. Amazon replaced it, no problem."
#     ],
#     "text1_keywords": ["worked extremely well", "crystal clear"],
#     "text2_keywords": ["cool and unique", "no problem"]
#   },
#   {
#     "dimension_title": "Acceptance to Rejection",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "All in all, its a good little; I mean little, player if you willing to take the gamble.",
#       "Although the HoMedics one when it works, isn't bad for the price...it's really a cheap product and will not last."
#     ],
#     "text2_evidence_sentences": [
#       "Nice try Belkin, come back when you have a product that works.",
#       "My advice is skip this unit."
#     ],
#     "text1_keywords": ["good little", "isn't bad for the price"],
#     "text2_keywords": ["Nice try", "skip this unit"]
#   }
# ]
# ```
# Tokens used: 3021
# Cost of the request: $0.000006
# Response: ```json
# [
#   {
#     "dimension_title": "Harsh Criticism to Disappointment",
#     "text1_sentence_count": 3,
#     "text2_sentence_count": 3,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 60,
#     "confidence_score_text2": 60,
#     "text1_evidence_sentences": [
#       "This was one of the worst books I have ever read.",
#       "I thought it stunk a few chapters in.",
#       "This was terrible; there are so many better ones out there!"
#     ],
#     "text2_evidence_sentences": [
#       "However, upon reading it I was more disappointed than delighted.",
#       "Once again I feel the sting of having read a book, studying each line, reading each word...only to be disappointed.",
#       "Very Disappointing I'm not sure where to start- from the painfully irrelevant details to the totally unrealistic murder description, this book was a waste of time."
#     ],
#     "text1_keywords": ["worst books", "stunk", "awful"],
#     "text2_keywords": ["disappointed", "disappointing", "waste of time"]
#   },
#   {
#     "dimension_title": "Anger to Resignation",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "it was so irritating to me that i am writing this review.",
#       "i guess the bottom line is i feel cheated!"
#     ],
#     "text2_evidence_sentences": [
#       "I admit that I didn't read much of it before I gave up - only the first NUM pages - so perhaps I am not the most reliable of reviewers, but this book was so much of a letdown for me that I could not stomach another word (or mention of the dreaded \"cinammon rolls\").",
#       "Since the author failed to deliver, I felt it not worth my time or effort to keep on reading."
#     ],
#     "text1_keywords": ["irritating", "feel cheated"],
#     "text2_keywords": ["gave up", "not worth my time"]
#   }
# ]
# ```
# Tokens used: 3323
# Cost of the request: $0.000007
# Response: ```json
# [
#   {
#     "dimension_title": "Disappointment to Frustration",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "Does not deliver what it promises I was disconcerted to find a very substandard book instead of what I had expected.",
#       "After going through this book, I can find nothing useful."
#     ],
#     "text2_evidence_sentences": [
#       "I was more frustrated with the book than I was with having to take the test.",
#       "A frustrating book due to its poor organization."
#     ],
#     "text1_keywords": ["disconcerted", "nothing useful"],
#     "text2_keywords": ["frustrated", "frustrating"]
#   },
#   {
#     "dimension_title": "Focus on Content to Focus on Presentation",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "I had ideas of receiving a really helpful book to make me a better technical recruiter, but I received a book of personal opinions and theoretical protocols that even I know better than to try, and I am pretty new at this.",
#       "After going through this book, I can find nothing useful."
#     ],
#     "text2_evidence_sentences": [
#       "The book itself is poorly organized.",
#       "Useful information also gets lost on the pages due to the layout."
#     ],
#     "text1_keywords": ["helpful book", "nothing useful"],
#     "text2_keywords": ["poorly organized", "layout"]
#   },
#   {
#     "dimension_title": "General Disapproval to Specific Criticism",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_score_text1": 40,
#     "confidence_label_text2": "Medium",
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "All in all bad book for GMAT Equations, Inequalities, & VIC's preparation.",
#       "Waste of money I should have listened to the other poor reviews and saved my money."
#     ],
#     "text2_evidence_sentences": [
#       "The questions are poorly worded, if your answer is wrong you are insulted and for a book based on the teaching of reading - it was full of typos.",
#       "Every time I turn to the index to look up a simple topic (e.g., \"paragraphs\" or \"spaces\"), it is invariably absent."
#     ],
#     "text1_keywords": ["bad book", "poor reviews"],
#     "text2_keywords": ["poorly worded", "typos"]
#   }
# ]
# ```
# Tokens used: 3164
# Cost of the request: $0.000006
# Response: ```json
# [
#   {
#     "dimension_title": "Excitement to Disappointment",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "Great Concept...Bad Quality Product I was so excited for this tub...",
#       "This toy arrived, well packed much earlier than I thought and I thank seller for this."
#     ],
#     "text2_evidence_sentences": [
#       "Dissappointed- toy not designed well I bought this for my DATE son and I hate it.",
#       "Add a B to Garage, and you get GARBAGE This was one of the toys we most looked forward to our DATE son opening."
#     ],
#     "text1_keywords": ["so excited", "thank seller"],
#     "text2_keywords": ["Dissappointed", "hate it"]
#   },
#   {
#     "dimension_title": "Durability Expectation to Fragility Reality",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "I just wasted $NUM of my hard earned money. I thought this would be durable and my daughter had to keep putting the parts back on all the time she said forget she had enough!",
#       "Wasn't impressed with quality."
#     ],
#     "text2_evidence_sentences": [
#       "We could NOT believe how shoddy the workmanship was.",
#       "On first conversion attempt, parts started falling apart and by end of DATE most of them have chipped away one by one even though I tried converting it carefully myself."
#     ],
#     "text1_keywords": ["would be durable", "impressed with quality"],
#     "text2_keywords": ["shoddy the workmanship", "falling apart"]
#   }
# ]
# ```
# Tokens used: 2860
# Cost of the request: $0.000006
# Response: ```json
# [
#   {
#     "dimension_title": "Acceptance to Disappointment",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "Nice Hot Dog Cooker for the Money I agree with some other reviews that say the switch feels flimsy and the lid hinges can get broken easily.",
#       "I still like the product for the $NUM I paid for it."
#     ],
#     "text2_evidence_sentences": [
#       "When I first got this, I was very excited.",
#       "I was so disappointed!"
#     ],
#     "text1_keywords": ["Nice Hot Dog Cooker", "I still like the product"],
#     "text2_keywords": ["very excited", "so disappointed"]
#   },
#   {
#     "dimension_title": "Durability Expectation to Premature Failure",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "I've been looking for a sturdy pair of poultry shears as all the ones with plastic handles I seem to break within DATE or two.",
#       "I liked the look of these with the solid metal handles and thought that I'd finally found a pair of shears worthy of my abuse..."
#     ],
#     "text2_evidence_sentences": [
#       "Broke after one use!",
#       "Junk Worked fine in the beginning but after DATE the plastic cracked."
#     ],
#     "text1_keywords": ["sturdy pair", "worthy of my abuse"],
#     "text2_keywords": ["Broke after one use", "plastic cracked"]
#   },
#   {
#     "dimension_title": "Functional Satisfaction to Functional Defect",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "nice when it works I received this unit as a gift DATE.",
#       "Nice milk and easy to switch between warm and frothy by such a simple stirring bar."
#     ],
#     "text2_evidence_sentences": [
#       "I made waffles one time and they were great.",
#       "When I took it out DATE to make waffles for the second time, it didn't work!"
#     ],
#     "text1_keywords": ["nice when it works", "easy to switch"],
#     "text2_keywords": ["they were great", "it didn't work"]
#   }
# ]
# ```
# Tokens used: 3277
# Cost of the request: $0.000007
# Response: ```json
# [
#   {
#     "dimension_title": "Mild Annoyance to Strong Disappointment",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "My only real complaint is the bottling.",
#       "No matter how hard I try to get it poured out, it still drips down the side and makes a mess."
#     ],
#     "text2_evidence_sentences": [
#       "This product is no better than the Pantene conditioner I use on a regular basis.I'm really disappointed and will continue to use it because it does smell good and it was so expensive (won't want to waste it)! But after this jar is used up I will not buy again.",
#       "Product description does not describe the product received. Someone made a mistake somewhere here in baffooning the buying public. Very poor reflection on Amazon Dot Com for supporting this type of behavior/product."
#     ],
#     "text1_keywords": ["complaint", "makes a mess"],
#     "text2_keywords": ["disappointed", "poor reflection"]
#   },
#   {
#     "dimension_title": "Cautious Optimism to Strong Rejection",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "It seems to be helping as I'm not seeing as much hair on my floors and clothes as before.",
#       "I will keep using this product."
#     ],
#     "text2_evidence_sentences": [
#       "i hate this product i bought this product for $NUM so i could do my hair for DATE well lets just say that was a big mistake my hair looked horrible i looked like a witch it made my hair very frizzy i even sprayed something that they recomended at the beauty store but it didnt help i ended up jumping back in the shower to get my hair back to normal.",
#       "This is as false as false advertisement can get."
#     ],
#     "text1_keywords": ["helping", "keep using"],
#     "text2_keywords": ["i hate this product", "false"]
#   },
#   {
#     "dimension_title": "Qualified Satisfaction to Unfairness",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "Wow! This does a great job on our tibetan mastiff as he blows his DATE under coat, and also works well on the cats.",
#       "It works better than any other brush I've used, and has greatly reduced the animal hair in our home."
#     ],
#     "text2_evidence_sentences": [
#       "Now all I need is a cheaper night moisturizer not because I can not afford it, I just think that high end cosmetic companies are abusing a woman's need to look good.",
#       "This is so unfair."
#     ],
#     "text1_keywords": ["great job", "works well"],
#     "text2_keywords": ["abusing", "unfair"]
#   }
# ]
# ```
# Tokens used: 3250
# Cost of the request: $0.000006
# Response: ```json
# [
#   {
#     "dimension_title": "Initial Enthusiasm to Subsequent Disappointment",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "I bought this printer DATE after great reviews.",
#       "One positive note is the Camedia software."
#     ],
#     "text2_evidence_sentences": [
#       "OmniPage NUM worked great at first.",
#       "Sure, this product works just great... until it breaks!!!"
#     ],
#     "text1_keywords": ["great reviews", "positive note"],
#     "text2_keywords": ["worked great", "works just great"]
#   },
#   {
#     "dimension_title": "Focus on Product Quality to Focus on Product Reliability",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "If you want a cheap camera, and don't care about having quality pictures to preserve, then this is the camera for you.",
#       "I have had my dealings with NUM.2mp cameras, some made in DATE and I am very appalled to have used this camera and to get this kind of low quality shot."
#     ],
#     "text2_evidence_sentences": [
#       "It has a very bad bug where it allows the audio and video to get out of sync when making DVDs (a showstopper in my opinion).",
#       "As of DATE, it won't even start up."
#     ],
#     "text1_keywords": ["quality pictures", "low quality shot"],
#     "text2_keywords": ["bad bug", "won't even start up"]
#   },
#   {
#     "dimension_title": "Emphasis on Physical Attributes to Emphasis on Functional Attributes",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "I like the small compact design but it's useless if it doesn't work.",
#       "I will say I love the design of the camera, and this just makes me want apple to delve into the camera industry."
#     ],
#     "text2_evidence_sentences": [
#       "I purchased a fairly top-of-the-line system just so I could use this product (NUM GHz Pentium NUM, NUM MHz bus, dedicated SATA NUM gig hard drive, NUM gig of NUM MHz DDR RAM), but am disappointed that I still have problems with version NUM.NUM.",
#       "First of all, the scanner installed pretty easily, no problems there."
#     ],
#     "text1_keywords": ["small compact design", "love the design"],
#     "text2_keywords": ["top-of-the-line system", "installed pretty easily"]
#   }
# ]
# ```
# Tokens used: 3609
# Cost of the request: $0.000007
# Response: ```json
# [
#   {
#     "dimension_title": "Mild Disappointment to Strong Disgust",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "I'm really disappointed how lame this \"game\" is.",
#       "Very disappointing that for all the conceptualizing, marketing, research and programing that goes into creating a game from scratch that they wouldn't have put a bit more \"umph\" into the actual game inself."
#     ],
#     "text2_evidence_sentences": [
#       "WHAT A F---ING WASTE OF MY F---ING MONEY!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!",
#       "This game really sucks."
#     ],
#     "text1_keywords": ["disappointed", "lame"],
#     "text2_keywords": ["WASTE OF MY MONEY", "sucks"]
#   },
#   {
#     "dimension_title": "Qualified Recommendation to Strong Rejection",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "Give this game a try for the NUM bucks.",
#       "this could be so much fun for you if your realy cant get a date but its just a game so do get to happy lol so if you like rpg and like the long crud games that some people dont get go for it i cant say much but its great and the pics are cool but it realy for DATE older if u ask me"
#     ],
#     "text2_evidence_sentences": [
#       "You would be better off spending your money somewhere else.",
#       "Dont buy this game. Trust me it sucks s--t."
#     ],
#     "text1_keywords": ["Give this game a try", "so much fun"],
#     "text2_keywords": ["better off spending", "Dont buy"]
#   }
# ]
# ```
# Tokens used: 3224
# Cost of the request: $0.000006
# Response: ```json
# [
#   {
#     "dimension_title": "Acceptance to Disappointment",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "I ignored all the hate mail and bought it anyway as I love the movie.",
#       "Too bad though as I really love the movie."
#     ],
#     "text2_evidence_sentences": [
#       "Very disappointed with DVD playing-skipping, missing content.",
#       "Image my disappointment to find that NUM of the episodes on the disk #NUM were damaged!"
#     ],
#     "text1_keywords": ["love the movie", "bought it anyway"],
#     "text2_keywords": ["disappointed", "missing content"]
#   },
#   {
#     "dimension_title": "Hope to Frustration",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_score_text1": 40,
#     "confidence_label_text2": "High",
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "DATE is in the mail. Hope its good.",
#       "I have been waiting for a region NUM dvd for a long time and I couldnt wait to watch this wonderful film on my widescreen HDTV"
#     ],
#     "text2_evidence_sentences": [
#       "I feel royally hipped.",
#       "complete bollocks."
#     ],
#     "text1_keywords": ["Hope its good", "couldnt wait"],
#     "text2_keywords": ["hipped", "bollocks"]
#   }
# ]
# ```
# Tokens used: 2773
# Cost of the request: $0.000006
# Response: ```json
# [
#   {
#     "dimension_title": "Deception to Disappointment",
#     "text1_sentence_count": 3,
#     "text2_sentence_count": 3,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 60,
#     "confidence_score_text2": 60,
#     "text1_evidence_sentences": [
#       "misleading The advertisement states an NUM inch plush doll and I got a NUM inch plush doll; I called the retailer and he said he hasn't had a chance to change the info on Amazon; yet it is still advertised as a NUM inch plush doll.",
#       "The product says it's NUM oz... nope that is a BIG FAT LIE!",
#       "Much to my utter amazement, I received only NUM blanket, not NUM as advertised."
#     ],
#     "text2_evidence_sentences": [
#       "I was mislead as well I cannot believe I didn't read the reviews!!!",
#       "The reletive who purchased it from her wishlist was disapointed that their gift was useless and will be returned.",
#       "Merchant shipped the wrong product The merchant shipped a completely different piece of software do not buy this product. I was very dissappointed."
#     ],
#     "text1_keywords": ["misleading", "advertisement", "BIG FAT LIE"],
#     "text2_keywords": ["mislead", "useless", "wrong product"]
#   },
#   {
#     "dimension_title": "Seller Negligence to Delivery Failure",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "After waiting DATE for my order to arrive I contacted the seller.",
#       "I have since e-mailed them again and I never got a reply."
#     ],
#     "text2_evidence_sentences": [
#       "You guys delivered it over DATE late.",
#       "The Book Never got Delivered I can't provide much of a review because I ordered it on DATE and as of NUM/NUM/NUM I did not receive it."
#     ],
#     "text1_keywords": ["waiting", "contacted the seller", "never got a reply"],
#     "text2_keywords": ["delivered it over", "Never got Delivered", "did not receive it"]
#   }
# ]
# ```
# Tokens used: 2640
# Cost of the request: $0.000005
# Response: ```json
# [
#   {
#     "dimension_title": "General Satisfaction to Specific Praise",
#     "text1_sentence_count": 3,
#     "text2_sentence_count": 3,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 60,
#     "confidence_score_text2": 60,
#     "text1_evidence_sentences": [
#       "Very happy and will continue to buy in the future.",
#       "I would recommend this to anyone.",
#       "I am very happy."
#     ],
#     "text2_evidence_sentences": [
#       "Product was just as I expected.",
#       "My wife was very happy with her birthday gift.",
#       "She loves it.... thanks!"
#     ],
#     "text1_keywords": ["Great experience", "recommend", "pleased"],
#     "text2_keywords": ["perfect condition", "good deal", "excellent condition"]
#   },
#   {
#     "dimension_title": "Focus on Delivery to Focus on Product Quality",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "Ships on time DATE.",
#       "arrived on time and in great condition."
#     ],
#     "text2_evidence_sentences": [
#       "The CD case is exactly what I was looking for and the price was unbeatable, even including shipping.",
#       "I also was a little worried that buying it online would result in a cheaply made product, but it turned out to be a very sturdy and well made product."
#     ],
#     "text1_keywords": ["Fast delivery", "quick delivery", "on time"],
#     "text2_keywords": ["sturdy", "well made", "unbeatable"]
#   }
# ]
# ```
# Tokens used: 1975
# Cost of the request: $0.000004
# Response: ```json
# [
#   {
#     "dimension_title": "Disappointment to Enjoyment",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "I was looking forward to it but was very disappointed.",
#       "This DVD did not hold my attention and was NOT it a good work out."
#     ],
#     "text2_evidence_sentences": [
#       "The aerobics section of this video is beginner/intermediate level and great!",
#       "It's fun and Karen is an excellent instructor."
#     ],
#     "text1_keywords": ["very disappointed", "thumbs down"],
#     "text2_keywords": ["is great", "still enjoy"]
#   },
#   {
#     "dimension_title": "Boredom to Engagement",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "After that it becomes mundane and VERY BORING.",
#       "That's if you can defeat boredom to the end."
#     ],
#     "text2_evidence_sentences": [
#       "there's so much variety that you will certainly not get bored.",
#       "Unique set makes it more interesting to look at than some other videos."
#     ],
#     "text1_keywords": ["VERY BORING", "defeat boredom"],
#     "text2_keywords": ["not get bored", "more interesting"]
#   },
#   {
#     "dimension_title": "Ineffectiveness to Effectiveness",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "this is not a workout at all - just a seies of dances (very good I admit and fun to do) - no worm up, no cool down",
#       "I didn't find this to be much of a workout at all."
#     ],
#     "text2_evidence_sentences": [
#       "You will sweat you butt off, I couldn't do all the routines but by my 4th workout I was improving.",
#       "This workout is definitly in my rotation of workouts."
#     ],
#     "text1_keywords": ["not a workout", "no worm up", "no cool down"],
#     "text2_keywords": ["sweat you butt off", "improving", "good workout"]
#   }
# ]
# ```
# Tokens used: 3363
# Cost of the request: $0.000007

# %%
print(prompt)
# Out:
# Role: You are a semantic narrative analyst. Your task is to identify all strong, directional narrative polarity dimensions that differentiate text1 from text2. These dimensions represent conceptual shifts in discourse (e.g., tone, stance, topic, moral framing) and must be grounded in explicit sentence-level evidence from both texts.
#
# Each dimension should reflect a transition from a pole dominant in text1 to a different pole dominant in text2. Only report a dimension if it meets all of the following criteria:
#
# 1. It is clearly directional (text1 → text2). Symmetric or bidirectional contrasts are invalid.
# 2. It is supported by at least two sentences from text1 and two from text2 that express the respective poles. Each "sentence" refers to a distinct, declarative statement.
# 3. The keywords and evidence sentences must clearly match the claimed direction of the shift. For completeness, to the extent of possible, provide keywords different from those contained in evidence sentences.
# 4. All dimensions must use **non-overlapping evidence** — no shared sentence can be used for more than one dimension.
# 5. Extract all keywords directly as quoted substrings from the texts. Do not infer, generalize, or paraphrase.
# 6. Return at most 5 dimensions. If more are possible, prioritize those with highest evidence and directional clarity.
# 7. If fewer than two sentence-aligned differences exist for a dimension, or if polarity is weak or ambiguous, do not report it. Return an empty list instead. Do not invent plausible but unsupported contrasts.
# 8. Avoid including dimensions that differ only in phrasing but share the same semantic direction and evidence.
# 9. All output must follow the structure in the example and be formatted as a valid JSON list. Do not include commentary or free-text explanations.
#
# To help you understand what a narrative dimension might look like, here are a few illustrative examples only:
# - "Skepticism to Confidence"
# - "Risk Taking to Risk Aversion"
# - "Criticism to Trust"
# - "Dissapointment to Enjoyment"
# - "Sarcasm to Genuineness"
#
# These are for inspiration only — do not anchor your analysis to these labels. Let the dimensions emerge from the texts.
#
# --- Output Format (JSON list) ---
#
# For each dimension, return the following fields:
#
# - "dimension_title": A short label summarizing the semantic shift (e.g., "Uncertainty to Optimism").
# - "text1_sentence_count": Number of sentences from text1 that support the origin pole (min 2).
# - "text2_sentence_count": Number of sentences from text2 that support the destination pole (min 2).
# - "confidence_label_text1": One of ["High", "Medium", "Low"], based on clarity and alignment for the text1 pole.
# - "confidence_label_text2": One of ["High", "Medium", "Low"], based on clarity and alignment for the text2 pole.
# - "confidence_score_text1": Percentage of total sentences in text1 that reflect the origin pole (e.g., 3 of 12 → 25%)
# - "confidence_score_text2": Percentage of total sentences in text2 that reflect the destination pole (e.g., 3 of 12 → 25%)
# - "text1_evidence_sentences": 2–3 quotes from text1 illustrating the origin pole.
# - "text2_evidence_sentences": 2–3 quotes from text2 illustrating the destination pole.
# - "text1_keywords": Quoted keywords or phrases typical of the origin pole (from text1).
# - "text2_keywords": Quoted keywords or phrases typical of the destination pole (from text2).
#
# --- Example Output Format ---
#
# [
#   {
#     "dimension_title": "Mistrust to Trust",
#     "text1_sentence_count": 4,
#     "text2_sentence_count": 3,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 75,
#     "confidence_score_text2": 62,
#     "text1_evidence_sentences": [
#       "The agency has consistently failed to provide transparent updates.",
#       "There is little reason to believe the data hasn't been manipulated.",
#       "Public skepticism is justified given the repeated delays."
#     ],
#     "text2_evidence_sentences": [
#       "Recent communications have been clear and consistent.",
#       "The public has responded positively to the new transparency measures.",
#       "Trust in the agency has notably increased according to the latest survey."
#     ],
#     "text1_keywords": ["failed to provide", "manipulated", "public skepticism"],
#     "text2_keywords": ["transparency", "clear and consistent", "trust"]
#   }
# ]
#
# --- Begin Text Analysis ---
#
# text1:
# 	- "Best Dance DVD - You will lose weight I was looking for something to spark my routine. I found a clip on youtube and liked what I saw. Checked out the price on Amazon and took a chance..the best [...] bucks I ever spent. You will sweat you butt off, I couldn't do all the routines but by my 4th workout I was improving. In DATE; NUM sessions I lost NUM IBS. I could not believe it. No DVD workout has did that before and trust me I have all of them. You actually have fun with this DVD, by the time you realize it you have done TIME. There isn't alot of teaching here so just follow along. I reminded me of the latin parties growing up in NYC. I loved the music and the lil gal is so energetic, she makes you want to go the extra mile. Try it, it is a nice break from circuit training.Loved it."
# 	- "It's a great old-fashioned high-impact aerobic workout I've used this workout at home for DATE an it's the best high-impact aerobic workout I've found--and I've tried a few! The music isn't as cheezy as most of them, and I think it's quite inspirational now. This workout starts out slowly, and then it picks up. What I like about it is if I don't feel up to it, I can keep my feet on the floor (not jump if I don't want to) and still feel like I had a good workout. I usually only do the aerobic portion which is only NUM mins, but there's also a toning portion targeting all those fun areas. This workout is definitly in my rotation of workouts."
# 	- "NOT a good workout! I am a belly dancer and I thought I might like this DVD because Hula is SO similar! I was looking forward to it but was very disappointed.DETAILS:I DID NOT like this "workout" at all. The first NUM minutes are fine - not bad at all. After that it becomes mundane and VERY BORING. It is VERY slow moving and yet . . . there is NOT ENOUGH CUEING.Since this is targeted to beginners the instructor should have BROKEN DOWN THE MOVES to make them understandable and more doable. She DOES NOT do this.MY SYNOPSIS:Beginners WILL get LOST and the more advanced will be BORED.This DVD did not hold my attention and was NOT it a good work out. I'm sorry. I have to say thumbs down! God bless."
# 	- "not a workout!!! I didnt have high expextations when I ordered this tape - I know from ecperience that NUM-NUM-NUM minute classes on the same tape might mean you have to run the tape in the middle of the exsersize or too match cool down/worm up or not enough. But having many of Janes workouts that work for me so well I desided to go for it, because I need more tapes for the time I am in harry fro work and I only have TIME.I was so dissappointed! this is not a workout at all - just a seies of dances (very good I admit and fun to do) - no worm up, no cool down, there is a note of TIME end but no streches or anything, there is no note that TIME ended - finally after TIME I had to go so I did my own quick cool down and stopped the tape ..Buy this tape ony if you need aerobic part for another workout and you dont mind switching the tapes all the time."
# 	- "Bland Workout I think a great spinning workout should consist of a variety of movements. If you've ever been to a high energy spin class, then that's how I prefer to workout. Target Heart Rate Training fails to be inspiring and fun. I rode TIME into the workout before I realized an overwhelming majority of the workout only consisted of flat roads. TIME towards to end, you do a short standing climb. That's if you can defeat boredom to the end.Also, the music is Christian pop rock. It's tolerable. However, the music levels are way too high. You can barely hear the instructor talk.Overall, I wouldn't recommend buying the DVD unless you can try it beforehand. I was lucky enough to buy the downloadable version for a fraction of the cost although I'm still out of $NUM."
#
# text2:
# 	- "Aerobics section is great The aerobics section of this video is beginner/intermediate level and great! It's fun and Karen is an excellent instructor. I also like that it's short. If you are an advanced exerciser, use this on your easy DATE or try something more difficult. Perfect for the average exerciser. Unique set makes it more interesting to look at than some other videos. I've had the video forever and still enjoy getting it out, although the bar section (I even bought the bar) never thrilled me."
# 	- "Pretty Hardcore for TIME I bought this DVD because even though I work out every day for a little over an hour, it was more like zoning-out. That having been said, even for a more Intermediate-Advanced exerciser like myself, it is VERY high impact. If you're nursing some injuries, even old ones, this may not be for you. I know that after jumping up-and-down for TIME straight my ancient hip injury started to bother me again. Truthfully, I will probably only do this workout when I don't have time for a trip to the gym. But I find her encouraging remarks and approach to exercise useful and will apply it to my regular workout."
# 	- "Great Mix I always enjoy the workouts that Prevention puts together - there's so much variety that you will certainly not get bored. Your heartrate will be up, but I was never gasping for breath (which is good!) Chris definitely has a cheerful personality that isn't overwhelming. She's encoraging, motivating, and makes you hit all the areas of your body. If your looking something that really intense, this video isn't it, but I still feel it's a decent workout. And it's broken up into seperate segments, so if you are crunched for time you can just do what your in the mood for."
# 	- "Don't get this unless you just love Kim This was a complete impulse buy for me, one I regretted as soon as I tried the workout. If you are anything other than a beginner, there is no challenge here. Kim keeps saying how hard everything is and acts as if working out is a burden to her. There is a lot of chatter. One positive is an interesting set. Other than that, there are so many good videos out there and this is not one of them! Don't waste your money, you will be disappointed. Also the emphasis in this workout isn't even the abs; therefore the video's title is a misnomer."
# 	- "Not really a workout I am of average fitness and have done a few dancing classes - and I didn't find this to be much of a workout at all. I also found that Carmen doesn't always explain the moves properly and there is a lot of focus on her looking sexy but not a lot on teaching you the moves. I bought the discs separately but I really wish that I had purchased the box set because some of the discs' aren't worth it. It's fun to watch and it's not bad for you but not worth it if you are looking for an actual workout."

# %%
print(response)
# Out:
# ```json
# [
#   {
#     "dimension_title": "Disappointment to Enjoyment",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "I was looking forward to it but was very disappointed.",
#       "This DVD did not hold my attention and was NOT it a good work out."
#     ],
#     "text2_evidence_sentences": [
#       "The aerobics section of this video is beginner/intermediate level and great!",
#       "It's fun and Karen is an excellent instructor."
#     ],
#     "text1_keywords": ["very disappointed", "thumbs down"],
#     "text2_keywords": ["is great", "still enjoy"]
#   },
#   {
#     "dimension_title": "Boredom to Engagement",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "After that it becomes mundane and VERY BORING.",
#       "That's if you can defeat boredom to the end."
#     ],
#     "text2_evidence_sentences": [
#       "there's so much variety that you will certainly not get bored.",
#       "Unique set makes it more interesting to look at than some other videos."
#     ],
#     "text1_keywords": ["VERY BORING", "defeat boredom"],
#     "text2_keywords": ["not get bored", "more interesting"]
#   },
#   {
#     "dimension_title": "Ineffectiveness to Effectiveness",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 40,
#     "confidence_score_text2": 40,
#     "text1_evidence_sentences": [
#       "this is not a workout at all - just a seies of dances (very good I admit and fun to do) - no worm up, no cool down",
#       "I didn't find this to be much of a workout at all."
#     ],
#     "text2_evidence_sentences": [
#       "You will sweat you butt off, I couldn't do all the routines but by my 4th workout I was improving.",
#       "This workout is definitly in my rotation of workouts."
#     ],
#     "text1_keywords": ["not a workout", "no worm up", "no cool down"],
#     "text2_keywords": ["sweat you butt off", "improving", "good workout"]
#   }
# ]
# ```
