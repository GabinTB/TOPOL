# %%
# !pip install datasets

# %%
import os
from dotenv import load_dotenv; load_dotenv()

from tqdm.notebook import tqdm
import pickle
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import json

from datasets import load_dataset

os.environ["PYTORCH_MPS_HIGH_WATERMARK_RATIO"] = "0.0"
import torch
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from sklearn.preprocessing import normalize
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity

from src.helpers import preprocessing as preproc
from src.helpers.postprocessing import from_list_to_string, safe_json_load
from src.helpers.sentiment_analysis import SentimentModel
from src.topol_modeling import TopolModeling as TOPOL
from src.openai_api import OPENAI_CLIENT, OpenAIEmbedding
from src.openai_api import chat_completion as openai_chat_completion
from src.google_ai_api import GGENAI_CLIENT, GoogleAIEmbedding, AdvancedGoogleAIEmbedding
from src.google_ai_api import chat_completion as google_chat_completion

# %%
DATA_PATH = os.getenv("DATA_PATH")
OUTPUTS_PATH = os.path.join(os.getenv("OUTPUTS_PATH"), "robustness_checks", "rb1")

DEVICE = torch.device("mps")
STOP_WORDS = list(ENGLISH_STOP_WORDS)
RANDOM_STATE = 42

# %% [markdown]
# # Getting data

# %%
dataset = load_dataset("amazon_polarity")
FILES_PREFIX = "amazon_reviews"

# %%
X_train = [f"{title} {text}" for title, text in zip(dataset['train']['title'], dataset['train']['content'])]
X_test = [f"{title} {text}" for title, text in zip(dataset['test']['title'], dataset['test']['content'])]

y_train = dataset['train']['label']
y_test = dataset['test']['label']

data = pd.DataFrame({ 'text': X_train, 'label': y_train })

# %%
N_SAMPLE = 5000

df_A = data[data['label'] == 1].sample(N_SAMPLE, random_state=RANDOM_STATE)
df_B = data[data['label'] == 0].sample(N_SAMPLE, random_state=RANDOM_STATE)
df = pd.concat([df_A, df_B], axis=0).reset_index(drop=True)

# %%
df
# Out:
#                                                    text  label
# 0     Perfect Mantra I've been looking for this mant...      1
# 1     Quality I'm just a little disapointed with the...      1
# 2     Exceptional murder-mystery writer scores big. ...      1
# 3     all the prodding questions you never wanted to...      1
# 4     Best Wok ever I am so glad I bought this wok. ...      1
# ...                                                 ...    ...
# 9995  Doesn't work for me While I applaud the focus ...      0
# 9996  Beyond Stupid One wonders about all the people...      0
# 9997  Buyer Be Very Wary The trusted leader in child...      0
# 9998  I'll bring earplugs to the state fair next yea...      0
# 9999  Melody The reason why I didn't like this produ...      0
#
# [10000 rows x 2 columns]

# %%
word_counts = df["text"].apply(lambda x: len(x.split()))
q1_word_counts = word_counts.quantile(0.25)
q2_word_counts = word_counts.quantile(0.50)
avg_word_counts = word_counts.mean()
q3_word_counts = word_counts.quantile(0.75)
q4_word_counts = word_counts.quantile(0.95)
plt.figure(figsize=(10, 5))
plt.hist(word_counts, bins=50, color='blue', alpha=0.7)
plt.axvline(q1_word_counts, color='red', linestyle='dashed', linewidth=1, label=f'Q1: {q1_word_counts:.2f}')
plt.axvline(q2_word_counts, color='green', linestyle='dashed', linewidth=1, label=f'Q2: {q2_word_counts:.2f}')
plt.axvline(avg_word_counts, color='orange', linestyle='dashed', linewidth=1, label=f'Avg: {avg_word_counts:.2f}')
plt.axvline(q3_word_counts, color='purple', linestyle='dashed', linewidth=1, label=f'Q3: {q3_word_counts:.2f}')
plt.axvline(q4_word_counts, color='brown', linestyle='dashed', linewidth=1, label=f'Q4: {q4_word_counts:.2f}')
plt.legend()
plt.xlabel("Word Count")
plt.ylabel("Frequency")
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# # Pre-processing data

# %% [markdown]
# ##### 1. Data cleaning

# %%
entities_to_mask = ["DATE", "TIME", "ORGANIZATION", "NUM", "LOCATION"]
STOP_WORDS += entities_to_mask

fpath = os.path.join(DATA_PATH, f"{FILES_PREFIX}_texts.pickle")
if os.path.exists(fpath):
    print(f"Loading cleaned texts from {fpath}")
    with open(fpath, "rb") as f:
        texts = pickle.load(f)
    print(f"Loaded {len(texts)} texts")
else:
    print(f"Generating cleaned texts for {len(df)} raw texts...")
    texts = []
    for i, row in tqdm(df.iterrows(), total=len(df)):
        cleaned_text = preproc.get_clean_text(row, entities_to_mask=entities_to_mask, max_lenght=5000)
        texts.append(cleaned_text)
    with open(fpath, "wb") as f:
        pickle.dump(texts, f)
    print(f"Saved {len(texts)} cleaned texts to {fpath}.")

df["text"] = texts
del fpath
# Out:
# Loading cleaned texts from /Users/tig1/Programming/TOPOL/data/amazon_reviews_texts.pickle
# Loaded 10000 texts

# %% [markdown]
# ##### 2. Embedding texts

# %%
EMBEDDING_MODEL = OpenAIEmbedding(model="text-embedding-3-small")
# EMBEDDING_MODEL = GoogleAIEmbedding(model="text-embedding-004")
# EMBEDDING_MODEL = AdvancedGoogleAIEmbedding(model='text-embedding-004', task='clustering')
# EMBEDDING_MODEL = SentenceTransformer('intfloat/multilingual-e5-large-instruct', device=DEVICE)

fpath = os.path.join(DATA_PATH, f"{FILES_PREFIX}_embeddings.pickle")
if os.path.exists(fpath):
    print(f"Loading embeddings from {fpath}")
    with open(fpath, "rb") as f:
        embeddings = pickle.load(f)
    print(f"Loaded {len(embeddings)} embeddings")
else:
    print(f"Generating embeddings for {len(df)} text...")
    embeddings = EMBEDDING_MODEL.encode(df["text"].tolist(), fast=False)
    with open(fpath, "wb") as f:
        pickle.dump(embeddings, f)
    print(f"Saved {len(embeddings)} embeddings to {fpath}.")

df["embedding"] = embeddings.tolist()
del fpath
# Out:
# Loading embeddings from /Users/tig1/Programming/TOPOL/data/amazon_reviews_embeddings.pickle
# Loaded 10000 embeddings

# %% [markdown]
# ##### 3.a. Sentiment Analysis: FinBERT

# %%
sentiment_model = SentimentModel(model_name="ProsusAI/finbert", device=DEVICE, n_special_tokens=5)

fpath = os.path.join(DATA_PATH, f"{FILES_PREFIX}_sentiments_finbert.pickle")
if os.path.exists(fpath):
    print(f"Loading sentiments from {fpath}")
    with open(fpath, "rb") as f:
        sentiments = pickle.load(f)
    print(f"Loaded {len(sentiments)} sentiments")
else:
    print(f"Generating sentiments for {len(df)} texts...")
    sentiments = []
    for idx, row in tqdm(df.iterrows(), total=len(df)):
        doc = row['text']
        temp_sentiment = sentiment_model(doc, truncation=False)
        sentiments.append(temp_sentiment)
    with open(fpath, "wb") as f:
        pickle.dump(sentiments, f)
    print(f"Saved {len(sentiments)} sentiments to {fpath}.")

df["sentiment_finbert"] = sentiments
df["sentiment_score_finbert"] = df["sentiment_finbert"].apply(sentiment_model.get_sentiment_score)
del fpath, sentiment_model
# Out:
# Device set to use mps
# Loading sentiments from /Users/tig1/Programming/TOPOL/data/amazon_reviews_sentiments_finbert.pickle
# Loaded 10000 sentiments

# %% [markdown]
# ##### 3.b. Sentiment Analysis: Multilingual DistilBERT

# %%
sentiment_model = SentimentModel(model_name="tabularisai/multilingual-sentiment-analysis", device=DEVICE, n_special_tokens=5)

fpath = os.path.join(DATA_PATH, f"{FILES_PREFIX}_sentiments_distilbert.pickle")
if os.path.exists(fpath):
    print(f"Loading sentiments from {fpath}")
    with open(fpath, "rb") as f:
        sentiments = pickle.load(f)
    print(f"Loaded {len(sentiments)} sentiments")
else:
    print(f"Generating sentiments for {len(df)} texts...")
    sentiments = []
    for idx, row in tqdm(df.iterrows(), total=len(df)):
        doc = row['text']
        temp_sentiment = sentiment_model(doc, truncation=False)
        sentiments.append(temp_sentiment)
    with open(fpath, "wb") as f:
        pickle.dump(sentiments, f)
    print(f"Saved {len(sentiments)} sentiments to {fpath}.")

df["sentiment_distilbert"] = sentiments
df["sentiment_score_distilbert"] = df["sentiment_distilbert"].apply(sentiment_model.get_sentiment_score)
del fpath, sentiment_model
# Out:
# Device set to use mps
# Loading sentiments from /Users/tig1/Programming/TOPOL/data/amazon_reviews_sentiments_distilbert.pickle
# Loaded 10000 sentiments

# %% [markdown]
# # TOPOL Modeling

# %% [markdown]
# ### Prepare data

# %%
data_A = df[df["label"] == 1].copy()
data_B = df[df["label"] == 0].copy()

# %%
plt.figure(figsize=(10, 5))
plt.hist(data_A["sentiment_score_finbert"].values, bins=50, alpha=0.5, label='Data A Sent. Score', color='blue')
plt.axvline(x=data_A["sentiment_score_finbert"].mean(), color='blue', linestyle='--', label='Data A Mean Score')
plt.hist(data_B["sentiment_score_finbert"].values, bins=50, alpha=0.5, label='Data B Sent. Score', color='red')
plt.axvline(x=data_B["sentiment_score_finbert"].mean(), color='red', linestyle='--', label='Data B Mean Score')
plt.axvline(x=0, color='black', linestyle='--')
plt.xlabel('Sentiment Score')
plt.ylabel('Frequency')
plt.xlim(-1, 1)
plt.legend()
plt.title('Sentiment Score Distribution for Data A and Data B (FinBERT)')
plt.savefig(os.path.join(OUTPUTS_PATH, f"{FILES_PREFIX}_sentiment_score_finbert_histogram.pdf"), format="pdf", bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.hist(data_A["sentiment_score_distilbert"].values, bins=50, alpha=0.5, label='Data A Sent. Score', color='blue')
plt.axvline(x=data_A["sentiment_score_distilbert"].mean(), color='blue', linestyle='--', label='Data A Mean Score')
plt.hist(data_B["sentiment_score_distilbert"].values, bins=50, alpha=0.5, label='Data B Sent. Score', color='red')
plt.axvline(x=data_B["sentiment_score_distilbert"].mean(), color='red', linestyle='--', label='Data B Mean Score')
plt.axvline(x=0, color='black', linestyle='--')
plt.xlabel('Sentiment Score')
plt.ylabel('Frequency')
plt.xlim(-1, 1)
plt.legend()
plt.title('Sentiment Score Distribution for Data A and Data B (DistilBERT)')
plt.savefig(os.path.join(OUTPUTS_PATH, f"{FILES_PREFIX}_sentiment_score_distilbert_histogram.pdf"), format="pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Prepare UMAP, Leiden and vectorizer model

# %%
umap_params = {
    'n_neighbors': 150, # Change that concerns the robustness check: increasing the number of neighbors
    # 'n_neighbors': 100, --- IGNORE ---
    'min_dist': 0.0,
    'metric': 'cosine',
    'random_state': RANDOM_STATE
}

leiden_params = {
    'resolution': 1.5,
    'modularity': 'dugue',
    'random_state': RANDOM_STATE,
}

vectorizer_model = CountVectorizer(stop_words=STOP_WORDS, ngram_range=(1, 2), max_features=10000)

topol_model = TOPOL(
    n_components=50,
    umap_model_params=umap_params,
    leiden_model_params=leiden_params,
    vectorizer_model=vectorizer_model,
    supervised=True,
)

# %% [markdown]
# ### TOPOL modeling analysis

# %%
topol_model.apply_modeling(
    df_A=data_A,
    df_B=data_B,
    n_top_freq_words=20,
    n_repr_docs=10,
    n_top_tf_idf_words=20
)
# Out:
# /Users/tig1/miniforge3/envs/topol/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/tig1/miniforge3/envs/topol/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /Users/tig1/miniforge3/envs/topol/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/tig1/miniforge3/envs/topol/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# UMAP applied successfully.
# Leiden clustering applied successfully.
# /Users/tig1/miniforge3/envs/topol/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:402: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['date', 'location', 'num', 'organization', 'time'] not in stop_words.
#   warnings.warn(
# Cluster information extracted successfully.

# %%
topol_model.dataset_A.cluster_info
# Out:
#     Cluster  Count                                          Top_Words  \
# 0         0    895  {'album': 662, 'cd': 630, 'date': 468, 'num': ...
# 1         1    721  {'book': 1332, 'read': 291, 'great': 269, 'goo...
# 2         2    709  {'movie': 680, 'date': 342, 'great': 341, 'num...
# 3         3    345  {'num': 264, 'great': 216, 'date': 136, 'good'...
# 4         4    825  {'book': 1190, 'read': 655, 'story': 335, 'dat...
# 5         5    487  {'num': 283, 'great': 265, 'good': 171, 'date'...
# 6         6    366  {'date': 228, 'num': 174, 'great': 169, 'good'...
# 7         7     68  {'book': 120, 'read': 48, 'num': 25, 'good': 2...
# 8         8     42  {'num': 50, 'kindle': 31, 'price': 18, 'great'...
# 9         9    154  {'date': 102, 'num': 73, 'great': 72, 'product...
# 10       10    108  {'game': 248, 'num': 109, 'fun': 50, 'great': ...
# 11       11     69  {'num': 89, 'camera': 64, 'great': 48, 'use': ...
# 12       12     80  {'workout': 56, 'great': 47, 'num': 46, 'time'...
# 13       13    131  {'great': 76, 'watch': 74, 'date': 55, 'good':...
#
#                                              Centroid  \
# 0   [0.011021580622926895, -0.009454082526642892, ...
# 1   [0.00024106182920323956, 0.017464843384315094,...
# 2   [0.002195221580550116, 0.026802834562254896, -...
# 3   [-0.005959874963140254, -0.00932443887006915, ...
# 4   [0.010178896352572889, 0.02315794229082354, -0...
# 5   [0.00019861279177299922, -0.002849272266257405...
# 6   [0.017023978031178697, 0.004121820609834884, -...
# 7   [0.008604792647287574, 0.03339389982712044, -0...
# 8   [0.008854748324319232, -0.0021432701365223955,...
# 9   [0.0038125259412812407, -0.0060153724965881315...
# 10  [0.007846997722649744, 0.015193235154988037, -...
# 11  [0.009235909826162717, -0.00701324716784006, -...
# 12  [-0.0023418841694365254, 0.010718034891033313,...
# 13  [0.007157775107993325, 0.001054924313789447, -...
#
#                                   2D_Centroid  \
# 0    [-3.853255332115642, 10.720587070294599]
# 1      [-2.19992374720752, 4.243432664342132]
# 2    [-2.1743981342221517, 7.483301439137318]
# 3      [4.015081671009893, 8.486965953439906]
# 4    [-3.1220232290210146, 5.281218666885838]
# 5      [4.152319672416123, 7.013857404309377]
# 6    [2.6665820785558942, 6.6783726944949455]
# 7   [-3.6438424587249756, 4.8630840006996605]
# 8    [0.9978979485375541, 6.7951148975463145]
# 9     [3.6920212994922292, 6.043656380145581]
# 10    [0.6596459034416411, 7.005612616185789]
# 11     [3.262499059455982, 8.488404294718867]
# 12   [0.35863388478755953, 5.907264184951782]
# 13    [2.1784139325600544, 7.408247314336646]
#
#                               Top_Representative_Docs  \
# 0   [One of the best albums of DATE Set aside copy...
# 1   [Cool ! Easy to read and best of all - it all ...
# 2   [Tons of great content I don't know of anythin...
# 3   [Almost perfect I absolutely love this product...
# 4   [This book rekindled my love for reading!!! I ...
# 5   [nothing like a quality utensil! I works as ad...
# 6   [good value My daughter DATE (then six) got th...
# 7   [Sad to see all of these one-star ratings I th...
# 8   [DATE My thoughts after NUM months:- Worth eve...
# 9   [Amazing! I love this stuff, my husband bought...
# 10  [Best "#@&%;!" Game Ever !! I have to say, I'v...
# 11  [Great camera for most casual users I got this...
# 12  [It's a great old-fashioned high-impact aerobi...
# 13  [Great Just want I wanted. Came in on time and...
#
#                                       Top_Words_TFIDF
# 0   {'cd': 0.41533197940001637, 'love': 0.16344568...
# 1   {'book': 0.4731626816578947, 'great': 0.239404...
# 2   {'movie': 0.30719505197635977, 'date': 0.28799...
# 3   {'num': 0.24720216311752694, 'product': 0.2472...
# 4   {'book': 0.42364364677139366, 'read': 0.247125...
# 5   {'good': 0.16119835883042, 'num': 0.1381700218...
# 6   {'date': 0.39166484350908715, 'love': 0.220188...
# 7   {'book': 0.42581357415359194, 'read': 0.277704...
# 8   {'kindle': 0.4882140544055973, 'num': 0.329999...
# 9   {'date': 0.3002984144673583, 'hair': 0.2144988...
# 10  {'game': 0.6005056932919556, 'num': 0.18015170...
# 11  {'great': 0.28309077906402874, 'camera': 0.283...
# 12  {'workout': 0.3946604935083885, 've': 0.194138...
# 13  {'condition': 0.3726504389529294, 'great': 0.2...

# %%
topol_model.dataset_B.cluster_info
# Out:
#     Cluster  Count                                          Top_Words  \
# 0         0    505  {'cd': 307, 'album': 293, 'like': 271, 'num': ...
# 1         1    661  {'book': 1278, 'num': 293, 'date': 188, 'don':...
# 2         2    618  {'movie': 838, 'film': 306, 'num': 260, 'time'...
# 3         3    798  {'num': 666, 'date': 660, 'time': 344, 'produc...
# 4         4     79  {'book': 97, 'read': 40, 'date': 31, 'story': ...
# 5         5    390  {'num': 218, 'date': 189, 'use': 121, 'just': ...
# 6         6    486  {'date': 262, 'num': 237, 'product': 137, 'tim...
# 7         7    729  {'book': 1222, 'read': 501, 'just': 285, 'like...
# 8         8    289  {'num': 335, 'date': 138, 'amazon': 117, 'prod...
# 9         9    156  {'product': 90, 'date': 73, 'like': 64, 'num':...
# 10       10    126  {'game': 305, 'num': 115, 'like': 57, 'games':...
# 11       11     87  {'camera': 82, 'num': 63, 'date': 56, 'printer...
# 12       12     68  {'dvd': 37, 'video': 34, 'just': 33, 'workout'...
# 13       13      8  {'watch': 9, 'date': 4, 'just': 4, 'work': 4, ...
#
#                                              Centroid  \
# 0   [0.004233782356221685, 0.006679507897782663, -...
# 1   [-0.005936004009850442, 0.0269436380964213, -0...
# 2   [-0.011103283626706118, 0.04373764780531434, -...
# 3   [-0.016714395316206294, 0.010080267473591234, ...
# 4   [0.006435037499567777, 0.03419880848525304, -0...
# 5   [-0.016075680334898396, 0.021558578069753146, ...
# 6   [0.00045649163102670745, 0.01998103178305993, ...
# 7   [0.002360149662402255, 0.04205493840482533, -0...
# 8   [-0.005785872988970015, 0.005954668012013212, ...
# 9   [-0.0071411622829589015, 0.0051650789644041555...
# 10  [-0.009187847997581561, 0.02934601609423038, -...
# 11  [-0.012356556286458622, 0.010861655947285298, ...
# 12  [-0.016415137752226333, 0.02279468821892378, -...
# 13  [9.479094296693802e-05, 0.03387702485633781, -...
#
#                                  2D_Centroid  \
# 0   [-3.118112311740913, 10.776562072262905]
# 1    [-2.603391220232362, 3.783362504393539]
# 2   [-2.6580554657769433, 8.028862712452712]
# 3     [4.006785147769708, 8.385383246835312]
# 4     [-3.501344182823278, 4.96554482737674]
# 5     [4.343822949819076, 7.081774301406664]
# 6    [3.1226972564748285, 6.989982838493316]
# 7     [-3.998173985788688, 4.51579255037347]
# 8    [1.9048337796155144, 7.654754247632406]
# 9      [3.735434666658059, 6.22145169820541]
# 10   [1.0342170799535417, 7.055465153285435]
# 11   [3.2330716094751466, 8.682180273121801]
# 12  [-0.3815035285318599, 5.875067100805395]
# 13    [3.069543167948723, 7.583537578582764]
#
#                               Top_Representative_Docs  \
# 0   [NUM well crafted songs does NOT make a great ...
# 1   [Does not deliver what it promises I was disco...
# 2   [What the hell did I just watch. I am a true B...
# 3   [Worthless - Do NOT buy I read the other revie...
# 4   [What a pity. The book starts off wonderfully ...
# 5   [An adjustable disappointment When I first got...
# 6   [Dissappointed- toy not designed well I bought...
# 7   [Very Disappointing I'm not sure where to star...
# 8   [Big Disappointment!!! Ordered the Verbatim NU...
# 9   [no good my dog would not touch his water with...
# 10  [WHAT A F---ING WASTE OF MY F---ING MONEY!!!!!...
# 11  [Don't waste your money I bought this printer ...
# 12  [NOT a good workout! I am a belly dancer and I...
# 13  [Not great for smaller wrists I am a woman who...
#
#                                       Top_Words_TFIDF
# 0   {'cd': 0.29479114175178583, 'songs': 0.2254285...
# 1   {'book': 0.6745139441374297, 'reviews': 0.1053...
# 2   {'movie': 0.39995308987292744, 'time': 0.16664...
# 3   {'date': 0.30386030578440154, 'unit': 0.202573...
# 4   {'book': 0.21796916788085396, 'time': 0.145312...
# 5   {'num': 0.211166614861127, 'water': 0.18886465...
# 6   {'date': 0.2616604543613524, 'time': 0.1962453...
# 7   {'book': 0.46772049511636976, 'read': 0.249450...
# 8   {'num': 0.38600246002466915, 'amazon': 0.23160...
# 9   {'product': 0.34898909162907765, 'hair': 0.225...
# 10  {'game': 0.584610417576877, 'num': 0.185364278...
# 11  {'camera': 0.28902255072198224, 'date': 0.2569...
# 12  {'workout': 0.31967711192958714, 'dvd': 0.2131...
# 13  {'watch': 0.29082028880917743, 'work': 0.18166...

# %%
fig, ax = topol_model.vizualize_clusters()
fig.savefig(os.path.join(OUTPUTS_PATH, f"{FILES_PREFIX}_topol_clusters.pdf"), format="pdf", bbox_inches='tight')
plt.show(fig, ax)
# Out:
# Drift computed successfully, ready to vizualize.

# %% [markdown]
# ### Drift analysis

# %%
no_nan_drifts = { k: v for k, v in topol_model.drifts.items() if isinstance(v, np.ndarray) }
drifts_df = pd.DataFrame.from_dict(no_nan_drifts, orient='index', columns=['x', 'y'])
drifts_df.index.name = "Cluster"

# %%
# Normalize drift vectors to unit length
unit_drifts = normalize(drifts_df.dropna().values, norm='l2')

k = 4
# # KMeans on unit vectors ≈ angular k-means (cosine similarity)
# kmeans = KMeans(n_clusters=k, random_state=RANDOM_STATE)
# drifts_df["labels"] = kmeans.fit_predict(unit_drifts)

# Compute angles in radians
angles = np.arctan2(unit_drifts[:, 1], unit_drifts[:, 0])   # range [-pi, pi]
angles = (angles + 2 * np.pi) % (2 * np.pi)                 # convert to [0, 2pi]
sector_size = 2 * np.pi / k                                 # Define number of angular sectors
labels = np.floor(angles / sector_size).astype(int)         # Assign each angle to a sector
drifts_df["labels"] = labels

# %%
colors = ['red', 'blue', 'green', 'orange', 'purple', 'pink', 'brown', 'gray']

fig, ax = plt.subplots(figsize=(8, 10))

for topic_id, row in drifts_df.iterrows():
    x, y, label_id = row['x'], row['y'], int(row['labels'])
    color = colors[label_id]
    ax.plot([0, x], [0, y], color=color, linewidth=2, label=f"Topic {topic_id}")
    ax.text(x, y, f"Topic {topic_id}", fontsize=9, color=color, ha='left', va='bottom')

lim = 2.1
ax.set_aspect('equal', 'box')
ax.set_xlim(-lim, lim); ax.set_ylim(-lim, lim)
ax.axhline(0, color='black', linewidth=0.5); ax.axvline(0, color='black', linewidth=0.5)
ax.set_frame_on(False)
fig.tight_layout()

fig.savefig(os.path.join(OUTPUTS_PATH, f"{FILES_PREFIX}_topol_drifts.pdf"), format="pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Drift explainability

# %%
fpath = os.path.join(DATA_PATH, "narrative_dimensions.pickle")
if os.path.exists(fpath):
    with open(fpath, "rb") as f:
        NARRATIVE_DIMENSIONS = pickle.load(f)
    print(f"Loaded {len(NARRATIVE_DIMENSIONS)} narrative dimensions from {fpath}")
else:
    raise FileNotFoundError(f"File {fpath} not found. Please generate narrative dimensions first.")
del fpath
# Out:
# Loaded 123 narrative dimensions from /Users/tig1/Programming/TOPOL/data/narrative_dimensions.pickle

# %%
fpath = os.path.join(DATA_PATH, "prompt_template.txt")
if os.path.exists(fpath):
    with open(fpath, "r") as f:
        PROMPT_TEMPLATE = f.read()
    print(f"Loaded prompt template from {fpath}")
else:
    raise FileNotFoundError(f"Prompt template file not found at {fpath}")
del fpath
# Out:
# Loaded prompt template from /Users/tig1/Programming/TOPOL/data/prompt_template.txt

# %%
def generate_narrative_comparison_prompt(text1, text2):
    prompt = PROMPT_TEMPLATE.replace("#####DIMENSIONS_LIST#####", from_list_to_string(NARRATIVE_DIMENSIONS))
    prompt = prompt.replace("#####TEXT1#####", text1)
    prompt = prompt.replace("#####TEXT2#####", text2)
    return prompt

# %%
# chat_completion_func = openai_chat_completion
chat_completion_func = google_chat_completion

# %%
zipped_representative_docs = list(zip(
    topol_model.dataset_A.cluster_info['Top_Representative_Docs'],
    topol_model.dataset_B.cluster_info['Top_Representative_Docs']
))
top_n_docs = 3  # Number of top documents to compare per cluster

for i, (top_docs_A, top_docs_B) in tqdm(enumerate(zipped_representative_docs), total=len(zipped_representative_docs)):

    # Get the representative documents for each cluster
    if top_n_docs is not None:
        text1 = from_list_to_string(top_docs_A[:top_n_docs])  # Take top N docs for cluster A
        text2 = from_list_to_string(top_docs_B[:top_n_docs])  # Take top N docs for cluster B
    else:
        text1 = from_list_to_string(top_docs_A)
        text2 = from_list_to_string(top_docs_B)

    # Generate the prompt for the LLM
    prompt = generate_narrative_comparison_prompt(text1, text2)
    response = chat_completion_func(prompt, max_tokens=1000000)

    # Dynamic response variable (you can also use a list or dict instead of naming each one)
    var_name = f"response_row{i}"
    globals()[var_name] = response

    # Parse the JSON response safely
    parsed_llm_out = safe_json_load(response)

    # Save to file
    with open(f"{OUTPUTS_PATH}/{FILES_PREFIX}_ND_row{i}.json", "w", encoding="utf-8") as f:
        json.dump(parsed_llm_out, f, ensure_ascii=False, indent=2)

    print(f"✅ Processed and saved row {i}")
# Out:
#   0%|          | 0/14 [00:00<?, ?it/s]
# Response: ```json
# [
#   {
#     "dimension_title": "Enthusiasm – Disappointment",
#     "polar_extremes_subtitle": "Enthusiasm – Disappointment",
#     "presence": "both",
#     "coverage_text1": 60,
#     "coverage_text2": 70,
#     "difference_confidence": 60,
#     "cosine_similarity": -0.4,
#     "text1_evidence_sentences": [
#       "This is one of those rare albums that each and every single song on there is absolutely amazing.",
#       "The kind of CD you put in car and enjoy the ride, because each song makes you move and sing along.",
#       "Just amazing stuff from someone who continues to amaze, even DATE."
#     ],
#     "text2_evidence_sentences": [
#       "Sorry folks, I hate to burst everyone's bubble - But this release is just not that good.",
#       "What a waste of hard earned cash!!! this CD was such bore with what seemed to be a complete lack of imagination",
#       "Very disappointing to me"
#     ]
#   },
#   {
#     "dimension_title": "High quality – Poor quality",
#     "polar_extremes_subtitle": "High quality – Poor quality",
#     "presence": "both",
#     "coverage_text1": 40,
#     "coverage_text2": 30,
#     "difference_confidence": 50,
#     "cosine_similarity": -0.3,
#     "text1_evidence_sentences": [
#       "This is a brilliant album, and a brilliant artist.",
#       "Definitely worth a listen.",
#       "Since her music is unique, I can only describe the work as a thoughtful, sometimes dark, but lyrically sound and musically engaging piece of art."
#     ],
#     "text2_evidence_sentences": [
#       "NUM well crafted songs does NOT make a great cd",
#       "I call this a dirty trick",
#       "In short, they all suck. Waste of time, waste of money."
#     ]
#   }
# ]
# ```
# Tokens used: 3215
# Cost of the request: $0.000006
# ✅ Processed and saved row 0
# Response: ```json
# [
#   {
#     "dimension_title": "Usefulness and Practicality",
#     "polar_extremes_subtitle": "Impractical/Theoretical – Useful/Practical",
#     "presence": "both",
#     "coverage_text1": 50,
#     "coverage_text2": 60,
#     "difference_confidence": 70,
#     "cosine_similarity": -0.65,
#     "text1_evidence_sentences": [
#       "Easy to read and best of all - it all makes sense.",
#       "A light reader with diagnostics and Rx that is heavily oriented to senior leaders' career peaks and waves but it has great personal advice for aspiring leaders' and mid careerist's leadership tool box.",
#       "Execellent book - very useful resource"
#     ],
#     "text2_evidence_sentences": [
#       "Does not deliver what it promises I was disconcerted to find a very substandard book instead of what I had expected.",
#       "I had ideas of receiving a really helpful book to make me a better technical recruiter, but I received a book of personal opinions and theoretical protocols that even I know better than to try, and I am pretty new at this.",
#       "This book was not interesting, not worth my time, not worth the money."
#     ]
#   },
#   {
#     "dimension_title": "Personal Growth vs. Stagnation",
#     "polar_extremes_subtitle": "Stagnation – Personal Growth",
#     "presence": "both",
#     "coverage_text1": 40,
#     "coverage_text2": 20,
#     "difference_confidence": 60,
#     "cosine_similarity": 0.2,
#     "text1_evidence_sentences": [
#       "But the most important thing it gave me was to open my eyes to my own self - and to see what was in my that thought that these men and their behaviours were acceptable.",
#       "Identifying pathologies is one thing, identifying your own unhealthy self-perceptions is the treasure and this book enables you to do that (if you're willing to take a look within).",
#       "Maximizing myself--from pushing myself to greater adventure to finding new ways of self-pleasuring--it truly is a matter of my choices. And that feels good!"
#     ],
#     "text2_evidence_sentences": [
#       "If you have been in the classroom for DATE don't even bother with this book. It's not going to help you improve your practice in any way",
#       "It seems to be for people who are CONSIDERING teaching and certainly has nothing to offer for someone who is already in the classroom."
#     ]
#   },
#   {
#     "dimension_title": "Value for Money",
#     "polar_extremes_subtitle": "Overpriced – Value for Money",
#     "presence": "both",
#     "coverage_text1": 10,
#     "coverage_text2": 20,
#     "difference_confidence": 30,
#     "cosine_similarity": -0.8,
#     "text1_evidence_sentences": [
#       "If you buy into life long learning philosophy - this book is for you."
#     ],
#     "text2_evidence_sentences": [
#       "Not worth it for the Price I was really excited when I bought this book, eager to improve my core workouts.",
#       "This book was not interesting, not worth my time, not worth the money.",
#       "I wish I could return this book."
#     ]
#   },
#   {
#     "dimension_title": "Quality and Organization",
#     "polar_extremes_subtitle": "Poor quality/Disorganized – High quality/Well-organized",
#     "presence": "text2 only",
#     "coverage_text1": 0,
#     "coverage_text2": 20,
#     "difference_confidence": 100,
#     "cosine_similarity": -1,
#     "text1_evidence_sentences": [],
#     "text2_evidence_sentences": [
#       "The book itself is poorly organized.",
#       "The first NUM pages are complete filler, so characteristic of poorly written workout literature.",
#       "The workouts outlined in the book are simply listed without pictures... what gives!"
#     ]
#   }
# ]
# ```
# Tokens used: 3603
# Cost of the request: $0.000007
# ✅ Processed and saved row 1
# Response: ```json
# [
#   {
#     "dimension_title": "Entertainment Value",
#     "polar_extremes_subtitle": "Enjoyable – Disappointing",
#     "presence": "both",
#     "coverage_text1": 80,
#     "coverage_text2": 90,
#     "difference_confidence": 85,
#     "cosine_similarity": -0.75,
#     "text1_evidence_sentences": [
#       "Tons of great content I don't know of anything else quite like this DVD.",
#       "This is possibly one of the best movies I've seen in a long time - I really appreciated the movie's theme.",
#       "I watched this movie over DATE, and I really loved it! There was a part where I even cried, this movie touches your heart and is something the entire family can watch."
#     ],
#     "text2_evidence_sentences": [
#       "What the hell did I just watch.",
#       "Boring as hell I waited so long to see this film and when I got to see it on dvd it was by far the worst movie I saw DATE.",
#       "This movie was amongst the worst I've ever seen in my entire life, and that includes several terrible Steven Seagal generic-CG stealth fighter movies."
#     ]
#   },
#   {
#     "dimension_title": "Production Quality",
#     "polar_extremes_subtitle": "High quality – Poor quality",
#     "presence": "both",
#     "coverage_text1": 10,
#     "coverage_text2": 5,
#     "difference_confidence": 70,
#     "cosine_similarity": -0.20,
#     "text1_evidence_sentences": [
#       "The short film selection is wonderful and wide ranging, from 'Chuck' a creepy chiller with a cool comentary to 'Hate (a comedy)' an hilarious spoof, to 'Moods of the Sea' a provacative montage cut to music from DATE."
#     ],
#     "text2_evidence_sentences": [
#       "Looks like a high school cinematography project",
#       "One look at the first CG'd monster and you'll laugh.",
#       "There is no cinematic quality here. Zero."
#     ]
#   },
#   {
#     "dimension_title": "Recommendation",
#     "polar_extremes_subtitle": "Recommended – Not recommended",
#     "presence": "both",
#     "coverage_text1": 10,
#     "coverage_text2": 5,
#     "difference_confidence": 95,
#     "cosine_similarity": -0.90,
#     "text1_evidence_sentences": [
#       "Buy it, ...",
#       "If you like family movies with a good ending, then you won't regret purchasing this DVD."
#     ],
#     "text2_evidence_sentences": [
#       "The best thing I can suggest for this dvd is that you use it as a frisbee to wing at someone.",
#       "Seriously, do not even CONSIDER renting this movie. Save your money, time, and the disappointment.",
#       "This one definately doesn't get my seal of approval."
#     ]
#   }
# ]
# ```
# Tokens used: 3354
# Cost of the request: $0.000007
# ✅ Processed and saved row 2
# Response: ```json
# [
#   {
#     "dimension_title": "Product Satisfaction",
#     "polar_extremes_subtitle": "Satisfaction – Dissatisfaction",
#     "presence": "both",
#     "coverage_text1": 70,
#     "coverage_text2": 80,
#     "difference_confidence": 60,
#     "cosine_similarity": -0.65,
#     "text1_evidence_sentences": [
#       "Almost perfect I absolutely love this product.",
#       "the sound and product quality are spectacular for the size and price.",
#       "pretty decent Love it, wireless works a lil faster"
#     ],
#     "text2_evidence_sentences": [
#       "Worthless - Do NOT buy",
#       "Very poor quality. It arrived defective.",
#       "Save your time & money After DATE of use (not even the whole day, TIME) the product wasn't working any more."
#     ]
#   },
#   {
#     "dimension_title": "Value for Money",
#     "polar_extremes_subtitle": "Value for money – Overpriced",
#     "presence": "both",
#     "coverage_text1": 20,
#     "coverage_text2": 15,
#     "difference_confidence": 50,
#     "cosine_similarity": -0.4,
#     "text1_evidence_sentences": [
#       "For this review, bottom line, it is a reasonable cost and does what it supposed to do ... it works.",
#       "Worth the money!"
#     ],
#     "text2_evidence_sentences": [
#       "Do yourself a favor, don't consider this junk",
#       "Save your time & money"
#     ]
#   },
#   {
#     "dimension_title": "Ease of Use",
#     "polar_extremes_subtitle": "User-friendly – Complicated",
#     "presence": "both",
#     "coverage_text1": 10,
#     "coverage_text2": 5,
#     "difference_confidence": 40,
#     "cosine_similarity": -0.2,
#     "text1_evidence_sentences": [
#       "NUM times easier to install than its predecessor."
#     ],
#     "text2_evidence_sentences": [
#       "I've wasted so much time and gone through some humility trying to fix this!!"
#     ]
#   },
#     {
#     "dimension_title": "Reliability",
#     "polar_extremes_subtitle": "Reliable – Buggy",
#     "presence": "text2 only",
#     "coverage_text1": 0,
#     "coverage_text2": 20,
#     "difference_confidence": 100,
#     "cosine_similarity": -1,
#     "text1_evidence_sentences": [],
#     "text2_evidence_sentences": [
#       "Each time I turn the dial and let go, it springs back to TIME past NUM instantly.",
#       "After DATE of use (not even the whole day, TIME) the product wasn't working any more.",
#       "My car was spitting the tape out."
#     ]
#   }
# ]
# ```
# Tokens used: 3066
# Cost of the request: $0.000006
# ✅ Processed and saved row 3
# Response: ```json
# [
#   {
#     "dimension_title": "Enjoyment of Reading",
#     "polar_extremes_subtitle": "Dislike of reading - Enjoyment of reading",
#     "presence": "both",
#     "coverage_text1": 70,
#     "coverage_text2": 30,
#     "difference_confidence": 80,
#     "cosine_similarity": -0.3,
#     "text1_evidence_sentences": [
#       "This book rekindled my love for reading!!!",
#       "Enjoy this book as much as I did, I promise that it'll be worth it!",
#       "A MOST PLEASANT READ What a pleasure...to be able to get comfortable in your recliner and have a 'good' read"
#     ],
#     "text2_evidence_sentences": [
#       "What a pity.",
#       "Just missing that something...",
#       "The plot was interesting, but it just never grabbed the reader and got them involved in the storyline."
#     ]
#   },
#   {
#     "dimension_title": "Narrative Satisfaction",
#     "polar_extremes_subtitle": "Narrative disappointment - Narrative satisfaction",
#     "presence": "both",
#     "coverage_text1": 30,
#     "coverage_text2": 70,
#     "difference_confidence": 90,
#     "cosine_similarity": -0.6,
#     "text1_evidence_sentences": [
#       "Pleasant Read! What a breath of fresh air this book was to read.",
#       "It left the reader very satisfied."
#     ],
#     "text2_evidence_sentences": [
#       "I was put off by the whole book in a matter of a few thousand words.",
#       "It was almost like to different authors.",
#       "And of the ending! And what he does with Clarice!"
#     ]
#   },
#   {
#     "dimension_title": "Plot Coherence",
#     "polar_extremes_subtitle": "Plot incoherence - Plot coherence",
#     "presence": "text2 only",
#     "coverage_text1": 0,
#     "coverage_text2": 30,
#     "difference_confidence": 100,
#     "cosine_similarity": -1,
#     "text1_evidence_sentences": [],
#     "text2_evidence_sentences": [
#       "But then all of a sudden he realizes he doesn't have the time needed to finish it so he rushes it and throws an ending together.",
#       "but terribly written with serious continuity problems."
#     ]
#   }
# ]
# ```
# Tokens used: 3224
# Cost of the request: $0.000006
# ✅ Processed and saved row 4
# Response: ```json
# [
#   {
#     "dimension_title": "Product Satisfaction",
#     "polar_extremes_subtitle": "Satisfaction – Disappointment",
#     "presence": "both",
#     "coverage_text1": 70,
#     "coverage_text2": 80,
#     "difference_confidence": 60,
#     "cosine_similarity": -0.65,
#     "text1_evidence_sentences": [
#       "nothing like a quality utensil!",
#       "I works as advertised!",
#       "overall highly, recommended.",
#       "It has a nice balance and feels good in my hands.",
#       "this is a great product"
#     ],
#     "text2_evidence_sentences": [
#       "An adjustable disappointment",
#       "The concept is great, the execution is poor.",
#       "WHAT A MISTAKE.",
#       "Poor quality",
#       "I was so excited to see this product on Amazon only to be greatly disappointed."
#     ]
#   },
#   {
#     "dimension_title": "Product Durability",
#     "polar_extremes_subtitle": "Durable – Fragile",
#     "presence": "both",
#     "coverage_text1": 30,
#     "coverage_text2": 70,
#     "difference_confidence": 75,
#     "cosine_similarity": -0.50,
#     "text1_evidence_sentences": [
#       "sturdily constructed, it seems it will last a very, very long time.",
#       "i loved it so much i wore it out, and got another one in DATE and i have worn it out also, i am starting on my third one"
#     ],
#     "text2_evidence_sentences": [
#       "the rubber gasket that seals the cup started to curl and warp.",
#       "even worse, the body filled with a little water. This was from hand washing, no dishwasher. No way to remove the water.",
#       "but after DATE it BREAKS!!",
#       "The plastic is of poor quality."
#     ]
#   },
#   {
#     "dimension_title": "Value for money",
#     "polar_extremes_subtitle": "Value for money – Overpriced",
#     "presence": "both",
#     "coverage_text1": 40,
#     "coverage_text2": 30,
#     "difference_confidence": 30,
#     "cosine_similarity": -0.10,
#     "text1_evidence_sentences": [
#       "decentforthemoney",
#       "what more can one ask."
#     ],
#     "text2_evidence_sentences": [
#       "Since I live in Europe, there is no point in returning the product and wasting more money."
#     ]
#   }
# ]
# ```
# Tokens used: 3185
# Cost of the request: $0.000006
# ✅ Processed and saved row 5
# Response: ```json
# [
#   {
#     "dimension_title": "Value for money",
#     "polar_extremes_subtitle": "Value for money – Overpriced",
#     "presence": "both",
#     "coverage_text1": 40,
#     "coverage_text2": 40,
#     "difference_confidence": 60,
#     "cosine_similarity": -0.2,
#     "text1_evidence_sentences": [
#       "The price is a little high but when kids like it this much and the toy last over a year, it is money well spent!",
#       "Instead of buying these items sperately over time, save yourself the money and buy this box (or add it to your baby shower gift list).",
#       "They are bright, attractive and easy to play with."
#     ],
#     "text2_evidence_sentences": [
#       "wasted my money completely",
#       "Overall, this item is not worth buying which is really disappointing because the concept is outstanding.",
#       "Problelm - made very cheaply and it reflects."
#     ]
#   },
#   {
#     "dimension_title": "High quality – Poor quality",
#     "polar_extremes_subtitle": "High quality – Poor quality",
#     "presence": "both",
#     "coverage_text1": 30,
#     "coverage_text2": 30,
#     "difference_confidence": 70,
#     "cosine_similarity": -0.3,
#     "text1_evidence_sentences": [
#       "The mat and pom-poms have held up well",
#       "The good news is it still DATEs just like it did when it was brand new.",
#       "They are small enough to throw a couple into a nappy bag (sorry, diaper bag) without creating bulk."
#     ],
#     "text2_evidence_sentences": [
#       "toy not designed well",
#       "made very cheaply and it reflects.",
#       "Great Concept...Bad Quality Product"
#     ]
#   },
#   {
#     "dimension_title": "Satisfaction – Disappointment",
#     "polar_extremes_subtitle": "Satisfaction – Disappointment",
#     "presence": "both",
#     "coverage_text1": 30,
#     "coverage_text2": 30,
#     "difference_confidence": 80,
#     "cosine_similarity": -0.4,
#     "text1_evidence_sentences": [
#       "That early disappointment turned into pure joy for her because she LOVED this!",
#       "My kids definately enjoyed it when the were younger.",
#       "A great baby shower gift!"
#     ],
#     "text2_evidence_sentences": [
#       "Dissappointed- toy not designed well",
#       "I hate it.",
#       "Overall, this item is not worth buying which is really disappointing because the concept is outstanding."
#     ]
#   }
# ]
# ```
# Tokens used: 3001
# Cost of the request: $0.000006
# ✅ Processed and saved row 6
# Response: ```json
# [
#   {
#     "dimension_title": "Appreciation of Artistry",
#     "polar_extremes_subtitle": "Artistic Appreciation – Literal Interpretation",
#     "presence": "both",
#     "coverage_text1": 50,
#     "coverage_text2": 50,
#     "difference_confidence": 60,
#     "cosine_similarity": 0.3,
#     "text1_evidence_sentences": [
#       "I think that the majority of these negative reviews come from readers who can't appreciate a novel from a truly artistic point of view.",
#       "CB is full of wonderful detail and exquisite storytelling.",
#       "As far as those who criticize having to re-read passages, do you really want a book that doesn't make you stop to think once in a while?"
#     ],
#     "text2_evidence_sentences": [
#       "I felt like the author was trying too hard to be deep and profound.",
#       "Often times the story would abruptly end and I would be left wondering if there was symbolic or poetic value in it ending where it did, or whether the author just got tired of writing and so ended the story.",
#       "The concept of the book sounded good but the execution was terrible."
#     ]
#   },
#   {
#     "dimension_title": "Character Development",
#     "polar_extremes_subtitle": "Well-developed Characters – Poorly-developed Characters",
#     "presence": "both",
#     "coverage_text1": 20,
#     "coverage_text2": 20,
#     "difference_confidence": 10,
#     "cosine_similarity": 0.5,
#     "text1_evidence_sentences": [
#       "The characters (especially Billy, who had a very limited voice) were very well developed, and the plot was well thought out.",
#       "The characters were great and saved the book, especially El Nino."
#     ],
#     "text2_evidence_sentences": [
#       "The other characters felt like filler, and the world as a whole was difficult to visualize."
#     ]
#   },
#   {
#     "dimension_title": "Plot Coherence",
#     "polar_extremes_subtitle": "Coherent Plot – Rambling Plot",
#     "presence": "both",
#     "coverage_text1": 15,
#     "coverage_text2": 15,
#     "difference_confidence": 20,
#     "cosine_similarity": 0.2,
#     "text1_evidence_sentences": [
#       "the plot was well thought out.",
#       "This compact life is really full of drama."
#     ],
#     "text2_evidence_sentences": [
#       "My issue with it was that the narrative felt rambling and disorganized.",
#       "In a scene where the main character has her first meeting with the vampires, the narrative gets so wrapped up in her talking about the past that I could barely follow what was going on."
#     ]
#   },
#   {
#     "dimension_title": "Pacing and Detail",
#     "polar_extremes_subtitle": "Balanced Pacing – Uneven Pacing",
#     "presence": "both",
#     "coverage_text1": 15,
#     "coverage_text2": 15,
#     "difference_confidence": 30,
#     "cosine_similarity": 0.1,
#     "text1_evidence_sentences": [
#       "I really enjoyed most of book... but it had an awkward pace.. Parts of it like the visit to Libby Hatches mothers house had me on edge. Other parts, like over descriptive dinner scenes were annoying."
#     ],
#     "text2_evidence_sentences": [
#       "It went on and on about the most unrelated details and when you get to the parts you'd think would be important, they were written in a way that didn't seem realistic in any sense."
#     ]
#   },
#   {
#     "dimension_title": "Ending Satisfaction",
#     "polar_extremes_subtitle": "Satisfying Ending – Disappointing Ending",
#     "presence": "both",
#     "coverage_text1": 0,
#     "coverage_text2": 0,
#     "difference_confidence": 30,
#     "cosine_similarity": 0.1,
#     "text1_evidence_sentences": [
#       "The end was disappointing. I won't spoil it for anyone who hasn't read it.. but a space ship could have landed to save DATE out of nowhere and had the same effect."
#     ],
#     "text2_evidence_sentences": [
#       "However, unwilling to leave this book without having given it every chance to redeem itself (or rather, the author, not the book) I read until the very end."
#     ]
#   }
# ]
# ```
# Tokens used: 3810
# Cost of the request: $0.000008
# ✅ Processed and saved row 7
# Response: ```json
# [
#   {
#     "dimension_title": "Customer Satisfaction",
#     "polar_extremes_subtitle": "Satisfaction – Dissatisfaction",
#     "presence": "both",
#     "coverage_text1": 70,
#     "coverage_text2": 80,
#     "difference_confidence": 60,
#     "cosine_similarity": -0.8,
#     "text1_evidence_sentences": [
#       "Worth every dollar. Best gadget I've owned.",
#       "I am very happy with my kindle.",
#       "I really enjoy my new kindle and the ease of reading has been very satisfactory."
#     ],
#     "text2_evidence_sentences": [
#       "Big Disappointment!!!",
#       "Very dis-appointed.",
#       "I received this product defective.",
#       "I had horrible customer service so I was forced to file a claim through amazon."
#     ]
#   },
#   {
#     "dimension_title": "Product Quality",
#     "polar_extremes_subtitle": "High quality – Poor quality",
#     "presence": "both",
#     "coverage_text1": 20,
#     "coverage_text2": 60,
#     "difference_confidence": 70,
#     "cosine_similarity": -0.6,
#     "text1_evidence_sentences": [
#       "Best gadget I've owned.",
#       "I treat everything else I purchase as equivalent Kindle Units."
#     ],
#     "text2_evidence_sentences": [
#       "the entire balance beam unit was completely sheered off of the base.",
#       "I realized that it was all due to cheap manufacturing, improper packing",
#       "I wanted one made in the USA and not some cheap copy from China."
#     ]
#   },
#   {
#     "dimension_title": "Ease of Use",
#     "polar_extremes_subtitle": "User-friendly – Complicated",
#     "presence": "text1 only",
#     "coverage_text1": 10,
#     "coverage_text2": 0,
#     "difference_confidence": 100,
#     "cosine_similarity": 0.0,
#     "text1_evidence_sentences": [
#       "I really enjoy my new kindle and the ease of reading has been very satisfactory."
#     ],
#     "text2_evidence_sentences": []
#   },
#   {
#     "dimension_title": "Reliability",
#     "polar_extremes_subtitle": "Reliable – Buggy",
#     "presence": "text2 only",
#     "coverage_text1": 0,
#     "coverage_text2": 40,
#     "difference_confidence": 100,
#     "cosine_similarity": 0.0,
#     "text1_evidence_sentences": [],
#     "text2_evidence_sentences": [
#       "Ordered the Verbatim NUM.5GB 6X Double Layer DVD+R DL Disks (20pk Spindle) and received NUM.4x Speed DVD+R DL Disks instead.",
#       "The second order came in DATE and the entire balance beam unit was completely sheered off of the base.",
#       "I received this product defective."
#     ]
#   },
#   {
#     "dimension_title": "Seller Responsibility",
#     "polar_extremes_subtitle": "Accountability – Irresponsibility",
#     "presence": "text2 only",
#     "coverage_text1": 0,
#     "coverage_text2": 20,
#     "difference_confidence": 100,
#     "cosine_similarity": 0.0,
#     "text1_evidence_sentences": [],
#     "text2_evidence_sentences": [
#       "She (amanda989) told me I had to send it to China, which was not specified in her returns policy.",
#       "I emailed her NUM more times requesting what she would send me, but she ignored me.",
#       "I had horrible customer service so I was forced to file a claim through amazon."
#     ]
#   }
# ]
# ```
# Tokens used: 3451
# Cost of the request: $0.000007
# ✅ Processed and saved row 8
# Response: ```json
# [
#   {
#     "dimension_title": "Product Satisfaction",
#     "polar_extremes_subtitle": "Satisfaction – Disappointment",
#     "presence": "both",
#     "coverage_text1": 70,
#     "coverage_text2": 80,
#     "difference_confidence": 60,
#     "cosine_similarity": -0.3,
#     "text1_evidence_sentences": [
#       "Amazing! I love this stuff.",
#       "I have sensitive skin and it does not bother me one bit.",
#       "I personally recommend this product!"
#     ],
#     "text2_evidence_sentences": [
#       "no good my dog would not touch his water with just a tiny drop of this stuff.",
#       "it didn't do a bit, not even the stain from lipsticks, spaghetti spots etc..",
#       "So, DATE after I spent $NUM on a dog toy, it was in the trashcan. I really don't consider my dog a chewer, so I was really disappointed in this toy/treat."
#     ]
#   },
#   {
#     "dimension_title": "Product Effectiveness",
#     "polar_extremes_subtitle": "Effective – Ineffective",
#     "presence": "both",
#     "coverage_text1": 60,
#     "coverage_text2": 70,
#     "difference_confidence": 50,
#     "cosine_similarity": -0.2,
#     "text1_evidence_sentences": [
#       "Worked for my kitty!",
#       "As soon as I bought this, I gave her some and she didn't seem to mind it.",
#       "Well by DATE she was eating again!"
#     ],
#     "text2_evidence_sentences": [
#       "it didn't do a bit, not even the stain from lipsticks, spaghetti spots etc...",
#       "my dog would not touch his water with just a tiny drop of this stuff.",
#       "I really don't consider my dog a chewer, so I was really disappointed in this toy/treat."
#     ]
#   },
#   {
#     "dimension_title": "Clarity of Instructions",
#     "polar_extremes_subtitle": "Clarity - Ambiguity",
#     "presence": "text2 only",
#     "coverage_text1": 0,
#     "coverage_text2": 20,
#     "difference_confidence": 100,
#     "cosine_similarity": -1,
#     "text1_evidence_sentences": [],
#     "text2_evidence_sentences": [
#       "I have to say that the packaging is not clear at all about this either - the rest of the bone is not supposed to be eaten.",
#       "mutt didn't understand that the only part that was edible was the inner portion of the toy."
#     ]
#   },
#   {
#     "dimension_title": "Scent Appreciation",
#     "polar_extremes_subtitle": "Pleasant Scent – Unpleasant Scent",
#     "presence": "text1 only",
#     "coverage_text1": 40,
#     "coverage_text2": 0,
#     "difference_confidence": 100,
#     "cosine_similarity": 1,
#     "text1_evidence_sentences": [
#       "The feature that originally got me to buy this shampoo from my salon was the fabulous scent.",
#       "It is a true citrus scent (thanks to essential oils) unlike most other \"orange\" or \"citrus\" shampoos on the market."
#     ],
#     "text2_evidence_sentences": []
#   }
# ]
# ```
# Tokens used: 3238
# Cost of the request: $0.000006
# ✅ Processed and saved row 9
# Response: ```json
# [
#   {
#     "dimension_title": "Enthusiasm – Disappointment",
#     "polar_extremes_subtitle": "Enthusiasm – Disappointment",
#     "presence": "both",
#     "coverage_text1": 50,
#     "coverage_text2": 50,
#     "difference_confidence": 70,
#     "cosine_similarity": -0.2,
#     "text1_evidence_sentences": [
#       "Best #@&%;! Game Ever !!",
#       "This game is probably the best I've ever played, and perhaps the best game I will ever play.",
#       "I really love this one."
#     ],
#     "text2_evidence_sentences": [
#       "WHAT A F---ING WASTE OF MY F---ING MONEY!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!",
#       "I'm really disappointed how lame this \"game\" is.",
#       "This game really sucks."
#     ]
#   },
#   {
#     "dimension_title": "Complexity – Simplicity",
#     "polar_extremes_subtitle": "Complexity – Simplicity",
#     "presence": "both",
#     "coverage_text1": 30,
#     "coverage_text2": 20,
#     "difference_confidence": 30,
#     "cosine_similarity": 0.1,
#     "text1_evidence_sentences": [
#       "The different movie spoofs throughout the game made it hard to stop once you start, wondering what was comming next.",
#       "I also enjoyed the various gameplay and different themes , and it was not hard to play, but not easy either , it was just right.",
#       "However, because of the wide range of possibilities, the game can be quite complex."
#     ],
#     "text2_evidence_sentences": [
#       "It is a lousy card kinda game with wierd rules.",
#       "The repetitive commentary between picking the cases gets annoying.",
#       "Granted - I've never heard of this game show (don't watch TV), but I was expecting a bit of gaming to be involved with this game."
#     ]
#   },
#   {
#     "dimension_title": "Value for Money – Overpriced",
#     "polar_extremes_subtitle": "Value for money – Overpriced",
#     "presence": "both",
#     "coverage_text1": 20,
#     "coverage_text2": 30,
#     "difference_confidence": 40,
#     "cosine_similarity": -0.3,
#     "text1_evidence_sentences": [
#       "Tons of extras, hidden characters, great effects, great music... and a very low price!",
#       "Buy it, you'll like it. trust me."
#     ],
#     "text2_evidence_sentences": [
#       "WHAT A F---ING WASTE OF MY F---ING MONEY!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!",
#       "If not dont waste NUM bucks on this game.",
#       "You would be better off spending your money somewhere else."
#     ]
#   }
# ]
# ```
# Tokens used: 3451
# Cost of the request: $0.000007
# ✅ Processed and saved row 10
# Response: ```json
# [
#   {
#     "dimension_title": "Product Satisfaction",
#     "polar_extremes_subtitle": "Satisfaction - Dissatisfaction",
#     "presence": "both",
#     "coverage_text1": 70,
#     "coverage_text2": 80,
#     "difference_confidence": 60,
#     "cosine_similarity": -0.85,
#     "text1_evidence_sentences": [
#       "This is overall a GREAT camera for those who want something better than your average point and shoot but don't want to spend the $ for the SLR.",
#       "I'll recommended to anyone, Great Price, Great Capacity...",
#       "I am extremely happy with my purchase and look forward to getting many DATE of use out of this camera."
#     ],
#     "text2_evidence_sentences": [
#       "I've been nothing but disappointed with this product.",
#       "I'M STUNNED AT HOW BAD THIS ITEM IS.",
#       "DO NOT BUY THIS CAMERA. . . at least, don't buy this camera if you want to actually have decent pictures to print and keep for a lifetime and for generations to come."
#     ]
#   },
#   {
#     "dimension_title": "Ease of Use",
#     "polar_extremes_subtitle": "User-friendly - Complicated",
#     "presence": "both",
#     "coverage_text1": 20,
#     "coverage_text2": 10,
#     "difference_confidence": 50,
#     "cosine_similarity": 0.3,
#     "text1_evidence_sentences": [
#       "It takes great pictures, the controls are very easy to figure out but spending TIME with the manual is a good idea.",
#       "I found this camera very easy to use right out of the box."
#     ],
#     "text2_evidence_sentences": [
#       "The scanner, copier and fax are all cumbersome to use...and the fax never has worked correctly.",
#       "I actually read the manual and learned how to use all the features and still NUM% of the pictures I've taken over DATE are blurred or very pixillated."
#     ]
#   },
#   {
#     "dimension_title": "Value for Money",
#     "polar_extremes_subtitle": "Value for money – Overpriced",
#     "presence": "both",
#     "coverage_text1": 10,
#     "coverage_text2": 10,
#     "difference_confidence": 70,
#     "cosine_similarity": -0.2,
#     "text1_evidence_sentences": [
#       "Great Price, Great Capacity, Good Performer on EOS 5D Nothing else beats 8gb under $NUM"
#     ],
#     "text2_evidence_sentences": [
#       "Within a very short period of time, the cartridges were empty, and the cost to replace each one was $NUM.",
#       "If not, save the $NUM+ dollars you would have spent, and budget for a more expensive, higher quality camera."
#     ]
#   }
# ]
# ```
# Tokens used: 3483
# Cost of the request: $0.000007
# ✅ Processed and saved row 11
# Response: ```json
# [
#   {
#     "dimension_title": "Workout Enjoyment",
#     "polar_extremes_subtitle": "Boredom/Frustration – Excitement/Enjoyment",
#     "presence": "both",
#     "coverage_text1": 50,
#     "coverage_text2": 50,
#     "difference_confidence": 75,
#     "cosine_similarity": -0.65,
#     "text1_evidence_sentences": [
#       "You actually have fun with this DVD, by the time you realize it you have done TIME.",
#       "I loved the music and the lil gal is so energetic, she makes you want to go the extra mile.",
#       "Aerobics section is great! It's fun and Karen is an excellent instructor."
#     ],
#     "text2_evidence_sentences": [
#       "After that it becomes mundane and VERY BORING.",
#       "This DVD did not hold my attention and was NOT it a good work out.",
#       "Don't waste your money, you will be disappointed."
#     ]
#   },
#   {
#     "dimension_title": "Workout Effectiveness",
#     "polar_extremes_subtitle": "Ineffective/Waste of Time – Effective/Time Well Spent",
#     "presence": "both",
#     "coverage_text1": 30,
#     "coverage_text2": 40,
#     "difference_confidence": 60,
#     "cosine_similarity": -0.50,
#     "text1_evidence_sentences": [
#       "You will sweat you butt off, I couldn't do all the routines but by my 4th workout I was improving.",
#       "In DATE; NUM sessions I lost NUM IBS. I could not believe it.",
#       "I can keep my feet on the floor (not jump if I don't want to) and still feel like I had a good workout."
#     ],
#     "text2_evidence_sentences": [
#       "Beginners WILL get LOST and the more advanced will be BORED.",
#       "This DVD did not hold my attention and was NOT it a good work out.",
#       "If you are anything other than a beginner, there is no challenge here."
#     ]
#   },
#   {
#     "dimension_title": "Instructor Charisma",
#     "polar_extremes_subtitle": "Uninspiring/Annoying – Inspiring/Charismatic",
#     "presence": "both",
#     "coverage_text1": 20,
#     "coverage_text2": 10,
#     "difference_confidence": 80,
#     "cosine_similarity": -0.40,
#     "text1_evidence_sentences": [
#       "the lil gal is so energetic, she makes you want to go the extra mile.",
#       "Karen is an excellent instructor.",
#       "I think it's quite inspirational now."
#     ],
#     "text2_evidence_sentences": [
#       "The lady's thick New York accent was a really annoying turn off.",
#       "Kim keeps saying how hard everything is and acts as if working out is a burden to her.",
#       "There is a lot of chatter."
#     ]
#   }
# ]
# ```
# Tokens used: 3391
# Cost of the request: $0.000007
# ✅ Processed and saved row 12
# Response: ```json
# [
#   {
#     "dimension_title": "Product Satisfaction",
#     "polar_extremes_subtitle": "Dissatisfaction – Satisfaction",
#     "presence": "both",
#     "coverage_text1": 70,
#     "coverage_text2": 80,
#     "difference_confidence": 85,
#     "cosine_similarity": -0.65,
#     "text1_evidence_sentences": [
#       "Great Just want I wanted.",
#       "Product was just as I expected.",
#       "Very happy and will continue to buy in the future."
#     ],
#     "text2_evidence_sentences": [
#       "Doesn't work I have a heavy Baume and Mercier watch...but the winder is useless and does not wind the watch at all.",
#       "Didn't work Didn't work for either a Timex watch or a Kenneth Cole watch.",
#       "This band is not great for a smaller wrist."
#     ]
#   },
#   {
#     "dimension_title": "Ease of Use",
#     "polar_extremes_subtitle": "Difficult to use – Easy to use",
#     "presence": "text2 only",
#     "coverage_text1": 0,
#     "coverage_text2": 20,
#     "difference_confidence": 90,
#     "cosine_similarity": -0.9,
#     "text1_evidence_sentences": [],
#     "text2_evidence_sentences": [
#       "Otherwise it was very easy to put on; I feared a lot of fiddling with the DATE bars, but they were a cinch to manipulate."
#     ]
#   },
#   {
#     "dimension_title": "Value for Money",
#     "polar_extremes_subtitle": "Overpriced – Value for money",
#     "presence": "text1 only",
#     "coverage_text1": 30,
#     "coverage_text2": 0,
#     "difference_confidence": 75,
#     "cosine_similarity": 0.8,
#     "text1_evidence_sentences": [
#       "Super present and a good deal!",
#       "The price was good and the service was great.",
#       "Thanks."
#     ],
#     "text2_evidence_sentences": []
#   }
# ]
# ```
# Tokens used: 2624
# Cost of the request: $0.000005
# ✅ Processed and saved row 13
